# %% [markdown]
# # 과제
# 아래 가이드에 따라 고객별 연간 구매데이터를 생성하고 아래사항을 수행하기(관측치 10,000개)

# %% [markdown]
# #### 고객 속성(id, 성별, 연령, 거주지역) 데이터와 거래 데이터를 통합한 데이터 프레임 df를 생성
#
# 거래 번호
# - id : 1 ~ 1000번 일련번호 - 개시 후 1천 건의 거래가 있었고 거기에 넘버링한 거라고 이해해보자
#
# 고객별 속성 데이터
# - cusno : 고객번호 1000개 랜덤(1,000명의 고객데이터가 있는 것)
# - gender : 0,1 정수 난수 생성
# - age : 0 ~ 80사이 정수 난수 생성
# - region : 1 ~ 10 사이 정수 난수 생성
#
# 거래 데이터
# - (date : 2020-01-01 ~ 2021-12-31 사이의 날짜 1000개 생성)
# - (day : 요일)
# - (time_20 : 01 ~ 24 사이 정수 난수 생성)
# - (time_21 : 01 ~ 24 사이 정수 난수 생성)
# - product_20 : 고가제품(10), 중가제품(20), 저가제품(30)로 구분제품코드 10,20,30
# - product_21 : 고가제품(10), 중가제품(20), 저가제품(30)로 구분제품코드 10,20,30
# - price_20 : 1000 ~ 50000 사이 실수 난수 생성
# - price_21 : 1000 ~ 50000 사이 실수 난수 생성
# - quantity_20 : 1 ~ 100 사이 정수 난수 생성
# - quantity_21 : 1 ~ 100 사이 정수 난수 생성
# - amount_20 : price_20 * quantity_20
# - amount_21 : price_21 * quantity_21
# - sales : 20년 대비 21년구매금액이 증가면 1, 감소면 0

# %% [markdown]
# ## [랜덤 데이터 생성]

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime 
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 고객 속성 데이터프레임 만들기

# %%
random.seed(1)

#고객별 속성 데이터프레임 만들기

cusno=np.arange(1001,2001)
#cusno=random.sample(list(range(1000,9000)),1000)
gender=np.random.choice([0,1],size=1000)
age=np.random.randint(10,81,size=1000)
region=np.random.randint(1,11,size=1000)

# %%
cusno=pd.Series(cusno)
gender=pd.Series(gender)
age=pd.Series(age)
region=pd.Series(region)

#시리즈 합쳐서 데이터프레임 만들기
customer=pd.concat([cusno,gender,age,region],axis=1)

#컬럼명 지정
customer.columns=['cusno','gender','age','region']

customer.head()
# Out:
#    cusno  gender  age  region
# 0   1001       1   44      10
# 1   1002       1   66       2
# 2   1003       1   60       2
# 3   1004       1   69       3
# 4   1005       0   80       7

# %% [markdown]
# ### 거래 데이터프레임 만들기

# %%
#빈 데이터프레임 만들기
purchase=pd.DataFrame(columns=['id','cusno','product','price','quantity','amount'])

# %%
#기본거래 데이터 만들기

#1. 거래 id 만들기
id=random.sample(list(range(10000,50000)),10000)

#2. 중복 cusno 만들기
cusno=np.random.randint(1001,2001,size=10000)   #기존 cusno가 중복될 수 있도록 만들기

#3. 기본거래 데이터 만들기
#product=np.random.choice([10,20,30],size=10000)
product=[random.randrange(10,40,10) for i in range(10000)]
price=np.random.uniform(1000,50000,size=10000).round(2)
quantity=np.random.randint(1,100,size=10000)
amount=price*quantity

# %%
#데이터프레임 채우기

purchase['id']=id
purchase['cusno']=cusno
purchase['product']=product
purchase['price']=price
purchase['quantity']=quantity
purchase['amount']=amount


purchase.head()
# Out:
#       id  cusno  product     price  quantity      amount
# 0  18805   1864       30  40244.46         8   321955.68
# 1  47303   1300       10  23508.50        18   423153.00
# 2  14135   1596       20   9412.06        50   470603.00
# 3  26716   1720       10  33403.01        46  1536538.46
# 4  17727   1302       30  24077.29        90  2166956.10

# %%
#날짜거래 데이터프레임 만들기

#1.date 
date_list=list(pd.date_range('2020-01-01','2021-12-31',freq='D')) #랜덤 선택을 위한 date 리스트

purchase['date']=np.random.choice(date_list,size=10000)

#2. day(요일) 
purchase['day']=purchase['date'].apply(lambda x: x.weekday())  #date별 요일을 숫자로 나타냄
purchase['day']=purchase['day'].replace(list(range(7)),['월','화','수','목','금','토','일'])

#3. 시간
purchase['time']=np.random.randint(1,25,size=10000)


purchase.head()
# Out:
#       id  cusno  product     price  quantity      amount       date day  time
# 0  18805   1864       30  40244.46         8   321955.68 2020-10-23   금    22
# 1  47303   1300       10  23508.50        18   423153.00 2020-08-07   금     2
# 2  14135   1596       20   9412.06        50   470603.00 2020-01-10   금    19
# 3  26716   1720       10  33403.01        46  1536538.46 2020-04-29   수    15
# 4  17727   1302       30  24077.29        90  2166956.10 2021-12-20   월    13

# %%
#id 데이터 앞에 연도 표시하기

purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10000 non-null  int64
#  1   cusno     10000 non-null  int64
#  2   product   10000 non-null  int64
#  3   price     10000 non-null  float64
#  4   quantity  10000 non-null  int64
#  5   amount    10000 non-null  float64
#  6   date      10000 non-null  datetime64[ns]
#  7   day       10000 non-null  object
#  8   time      10000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(1)
# memory usage: 703.2+ KB

# %%
purchase['id']=purchase.apply(lambda x: str(x.date.year-2000)+str(x.id), axis=1)
purchase.head()
# Out:
#         id  cusno  product     price  quantity      amount       date day  \
# 0  2018805   1864       30  40244.46         8   321955.68 2020-10-23   금
# 1  2047303   1300       10  23508.50        18   423153.00 2020-08-07   금
# 2  2014135   1596       20   9412.06        50   470603.00 2020-01-10   금
# 3  2026716   1720       10  33403.01        46  1536538.46 2020-04-29   수
# 4  2117727   1302       30  24077.29        90  2166956.10 2021-12-20   월
#
#    time
# 0    22
# 1     2
# 2    19
# 3    15
# 4    13

# %%
#데이터프레임 통합: 공통 변수 cusno를 활용해 데이터 결합
df=customer.merge(purchase,on='cusno',how='outer')
df.head(10)
# Out:
#    cusno  gender  age  region       id  product     price  quantity  \
# 0   1001       1   44      10  2031053       10  22629.49        51
# 1   1001       1   44      10  2023668       30  38189.40         6
# 2   1001       1   44      10  2019041       20  40676.45        19
# 3   1001       1   44      10  2122019       30  16963.33        12
# 4   1001       1   44      10  2047425       10  24472.45         7
# 5   1001       1   44      10  2019308       10  44949.69        49
# 6   1001       1   44      10  2040181       20  38745.81        88
# 7   1001       1   44      10  2039779       30  47083.44        92
# 8   1001       1   44      10  2020407       30   8426.53         8
# 9   1001       1   44      10  2148389       10  36711.73        27
#
#        amount       date day  time
# 0  1154103.99 2020-07-10   금     2
# 1   229136.40 2020-03-20   금     7
# 2   772852.55 2020-03-08   일    15
# 3   203559.96 2021-06-30   수     6
# 4   171307.15 2020-03-17   화    24
# 5  2202534.81 2020-02-25   화    23
# 6  3409631.28 2020-04-15   수    16
# 7  4331676.48 2020-09-09   수     8
# 8    67412.24 2020-03-11   수     7
# 9   991216.71 2021-01-29   금     7

# %%
#데이터프레임에 null 값이 없는지 확인

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cusno     10000 non-null  int64
#  1   gender    10000 non-null  int64
#  2   age       10000 non-null  int64
#  3   region    10000 non-null  int64
#  4   id        10000 non-null  object
#  5   product   10000 non-null  int64
#  6   price     10000 non-null  float64
#  7   quantity  10000 non-null  int64
#  8   amount    10000 non-null  float64
#  9   date      10000 non-null  datetime64[ns]
#  10  day       10000 non-null  object
#  11  time      10000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(2)
# memory usage: 1015.6+ KB

# %% [markdown]
# ---

# %% [markdown]
# ## [데이터 전처리]

# %%
#age 범주화

def age_category(x):
    y = 0
    if x< 20:
        y = 10
    elif x< 30:
        y = 20
    elif x< 40:
        y = 30
    elif x < 50:
        y = 40
    elif x< 60:
        y = 50
    else:
        y = 60
    return y

df['age_c']=df['age'].apply(age_category)
df.head()
# Out:
#    cusno  gender  age  region       id  product     price  quantity  \
# 0   1001       1   44      10  2031053       10  22629.49        51
# 1   1001       1   44      10  2023668       30  38189.40         6
# 2   1001       1   44      10  2019041       20  40676.45        19
# 3   1001       1   44      10  2122019       30  16963.33        12
# 4   1001       1   44      10  2047425       10  24472.45         7
#
#        amount       date day  time  age_c
# 0  1154103.99 2020-07-10   금     2     40
# 1   229136.40 2020-03-20   금     7     40
# 2   772852.55 2020-03-08   일    15     40
# 3   203559.96 2021-06-30   수     6     40
# 4   171307.15 2020-03-17   화    24     40

# %%
#데이터 순서를 날짜, 시간으로 정렬

df=df.sort_values(['date','time'],ignore_index=True)  #인덱스 무시
df.head()
# Out:
#    cusno  gender  age  region       id  product     price  quantity  \
# 0   1428       1   56       4  2022963       20  49985.19        72
# 1   1365       0   16       4  2036517       20  40944.64        41
# 2   1742       0   80       8  2024064       30   5431.92        55
# 3   1848       0   43       7  2011718       30  41080.53        21
# 4   1821       0   45       7  2023265       30  10682.83         8
#
#        amount       date day  time  age_c
# 0  3598933.68 2020-01-01   수     9     50
# 1  1678730.24 2020-01-01   수    12     10
# 2   298755.60 2020-01-01   수    12     60
# 3   862691.13 2020-01-01   수    12     40
# 4    85462.64 2020-01-01   수    16     40

# %% [markdown]
# ## [원시데이터 요약 및 현황 파악]

# %%
# 데이터 요약
df.describe()
# Out:
#               cusno        gender           age        region      product  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean    1498.929000      0.473000     44.530600      5.421100     19.88200
# std      287.660245      0.499295     20.947791      2.896518      8.17146
# min     1001.000000      0.000000     10.000000      1.000000     10.00000
# 25%     1252.000000      0.000000     25.000000      3.000000     10.00000
# 50%     1498.000000      0.000000     45.000000      5.000000     20.00000
# 75%     1745.000000      1.000000     63.000000      8.000000     30.00000
# max     2000.000000      1.000000     80.000000     10.000000     30.00000
#
#               price      quantity        amount          time         age_c
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean   25505.735225     49.745500  1.268205e+06     12.508800     38.364000
# std    14203.514940     28.397665  1.088257e+06      6.917594     18.415684
# min     1003.830000      1.000000  1.324400e+03      1.000000     10.000000
# 25%    13163.590000     25.750000  3.700664e+05      6.000000     20.000000
# 50%    25512.450000     49.000000  9.687835e+05     13.000000     40.000000
# 75%    37775.675000     74.000000  1.926218e+06     18.000000     60.000000
# max    49998.780000     99.000000  4.911192e+06     24.000000     60.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cusno     10000 non-null  int64
#  1   gender    10000 non-null  int64
#  2   age       10000 non-null  int64
#  3   region    10000 non-null  int64
#  4   id        10000 non-null  object
#  5   product   10000 non-null  int64
#  6   price     10000 non-null  float64
#  7   quantity  10000 non-null  int64
#  8   amount    10000 non-null  float64
#  9   date      10000 non-null  datetime64[ns]
#  10  day       10000 non-null  object
#  11  time      10000 non-null  int64
#  12  age_c     10000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(2)
# memory usage: 1015.8+ KB

# %%
df.corr()
# Out:
#              cusno    gender       age    region   product     price  \
# cusno     1.000000 -0.051596 -0.042869 -0.052619  0.013778  0.005863
# gender   -0.051596  1.000000  0.083297  0.047937 -0.013773 -0.008136
# age      -0.042869  0.083297  1.000000 -0.007804  0.004117  0.003345
# region   -0.052619  0.047937 -0.007804  1.000000  0.006832  0.001687
# product   0.013778 -0.013773  0.004117  0.006832  1.000000  0.001999
# price     0.005863 -0.008136  0.003345  0.001687  0.001999  1.000000
# quantity  0.003733 -0.013812 -0.004575 -0.007970  0.009365 -0.001464
# amount    0.002924 -0.015626 -0.003116 -0.002077  0.010574  0.649314
# time      0.008721 -0.012527 -0.022092  0.003586 -0.013198  0.015860
# age_c    -0.035691  0.081883  0.977769 -0.003170  0.001575  0.002381
#
#           quantity    amount      time     age_c
# cusno     0.003733  0.002924  0.008721 -0.035691
# gender   -0.013812 -0.015626 -0.012527  0.081883
# age      -0.004575 -0.003116 -0.022092  0.977769
# region   -0.007970 -0.002077  0.003586 -0.003170
# product   0.009365  0.010574 -0.013198  0.001575
# price    -0.001464  0.649314  0.015860  0.002381
# quantity  1.000000  0.662867 -0.002061 -0.004064
# amount    0.662867  1.000000  0.010454 -0.002857
# time     -0.002061  0.010454  1.000000 -0.018760
# age_c    -0.004064 -0.002857 -0.018760  1.000000

# %%
import matplotlib as mat
mat.rcParams['font.family'] = 'NanumGothic'

# %%
# 지역에 따른 연령대 파악
sns.barplot(data=df,x='region',y='age', ci=None)
# Out:
# <AxesSubplot:xlabel='region', ylabel='age'>
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
sns.pairplot(df[['region','age']])

# %%
sns.barplot(data=df,x='region',y='age',hue='gender', ci=None)
# Out:
# <AxesSubplot:xlabel='region', ylabel='age'>

# %%
sns.boxplot(x='age_c',y='amount', data=df, color='skyblue')
# Out:
# <AxesSubplot:xlabel='age_c', ylabel='amount'>

# %% [markdown]
# ### 위 그래프 인사이트
# - 정규분포로  나이대별 성별별 지역별 거의 차이가 없음
# - 주요 고객층은 40~45세, 성별은 거의 차이가 없음
# - 7번 지역은 남성 고객이 월등하게 높음

# %% [markdown]
# ### [지금 우리 회사는?]
# - 하이마트
# - 지역 범위 : 인구 비율 상위 10위 시 대상
#     - 서울 부산 인천 대구 대전 광주 경기도수원 울산 경기도고양 경기도용인
#
# - 가격대별 주요 고객층 :
#     - 저가 10 :
#         - 전연령대 분포 (충전기, 전기포트, 전자레인지, 드라이기…)
#     - 중가 20 :
#         - 30대 이상, 취미(스피커, 커피머신, 사양 좋은 컴퓨터)
#     - 고가 30 :
#         - 30-40대 신혼 가구(대형 가전 냉장고, tv, 세탁기, 건조기, 에어컨 ..)
#         - 40-50대(부모님 선물: 안마의자)

# %%
#제품코드에 따라 price, quantity, amount, sales 조정

#price, quantity 조정 (단위: 만원)
# 10 : 저렴한 제품류 / 20: 소형 가전 / 30: 중대형가전
def price_set(x):
    if x==10: 
        y= np.random.randint(1,100)
    elif x==20:
        y= np.random.randint(100,500)
    elif x==30: 
        y= np.random.randint(500,2000)
    return y

# 구매수량 조정
def quantity_set(x):
    if x==10: 
        z= np.random.randint(1,21)
    elif x==20:
        z= np.random.randint(1,11)
    elif x==30: 
        z= np.random.randint(1,6)
    return z

df['price']=df['product'].apply(price_set)
df['quantity']=df['product'].apply(quantity_set)


#amount 조정

df['amount']=df['price']*df['quantity']

# time 제거 
df.drop('time',axis=1,inplace=True)

df.head()
# Out:
#    cusno  gender  age  region       id  product  price  quantity  amount  \
# 0   1428       1   56       4  2022963       20    330         3     990
# 1   1365       0   16       4  2036517       20    277         3     831
# 2   1742       0   80       8  2024064       30   1022         5    5110
# 3   1848       0   43       7  2011718       30   1674         2    3348
# 4   1821       0   45       7  2023265       30   1858         3    5574
#
#         date day  age_c
# 0 2020-01-01   수     50
# 1 2020-01-01   수     10
# 2 2020-01-01   수     60
# 3 2020-01-01   수     40
# 4 2020-01-01   수     40

# %%
# 나중에 쓸 것
def extract_ym(date):
    year = str(date.year)
    month = date.month
    
    if month<10:
        month = '0'+ str(month)
        
    return year + str(month)

date_ym = df.set_index('date').groupby(extract_ym).sum()[['amount']]
date_ym
# Out:
#         amount
# date
# 202001  854666
# 202002  684667
# 202003  756590
# 202004  817430
# 202005  845013
# 202006  766301
# 202007  848508
# 202008  802275
# 202009  871564
# 202010  879980
# 202011  860998
# 202012  902026
# 202101  758737
# 202102  733513
# 202103  822949
# 202104  693753
# 202105  830077
# 202106  757777
# 202107  814155
# 202108  846493
# 202109  874790
# 202110  843812
# 202111  813519
# 202112  841939

# %% [markdown]
# ### 지역별 인구 수 참조 (통계청 자료 기반) 가중치 부여(kosis 행정 지역별 인구 분포)
#
# ```
# 1 서울특별시	9,500,480	25.22%
# 2 부산광역시	3,340,214	8.87%
# 3 대구광역시	2,378,573	6.31%
# 4 인천광역시	2,953,260	7.84%
# 5 광주광역시	1,436,916	3.81%
# 6 대전광역시	1,449,360	3.85%
# 7 울산광역시	1,117,204	2.97%
# 8 세종특별자치시	378,196	1.00%
# 9 경기도	13,577,808	36.04%
# 10 강원도	1,539,038	4.09%
#
# ```

# %%
df.region.value_counts()
# Out:
# 1     1091
# 8     1083
# 7     1062
# 3     1050
# 10    1035
# 2     1014
# 4     1007
# 5      939
# 6      900
# 9      819
# Name: region, dtype: int64

# %%
df1 = df.copy()
df1.region.value_counts()
# Out:
# 1     1091
# 8     1083
# 7     1062
# 3     1050
# 10    1035
# 2     1014
# 4     1007
# 5      939
# 6      900
# 9      819
# Name: region, dtype: int64

# %%
# 인구 분포 별 거래 데이터 지역 세팅
#df1.sample(n=2522,axis=0,replace=True)

a1 = df1.sample(n=2522,axis=0,replace=True)
a1['new_region'] = 1
#df1.remove(a1,axis=0)

a2 = df1.sample(n=887,axis=0,replace=True)
a2['new_region'] = 2
#df1.remove(a2,axis=0)

a3 = df1.sample(n=631,axis=0,replace=True)
a3['new_region'] = 3
#df1.remove(a3,axis=0)

a4 = df1.sample(n=784,axis=0,replace=True)
a4['new_region'] = 4
#df1.remove(a4,axis=0)

a5 = df1.sample(n=381,axis=0,replace=True)
a5['new_region'] = 5
#df1.remove(a5,axis=0)

a6 = df1.sample(n=385,axis=0,replace=True)
a6['new_region'] = 6
#df1.remove(a6,axis=0)

a7 = df1.sample(n=297,axis=0,replace=True)
a7['new_region'] = 7
#df1.remove(a7,axis=0)

a8 = df1.sample(n=100,axis=0,replace=True)
a8['new_region'] = 8
#df1.remove(a8,axis=0)

a9 = df1.sample(n=3604,axis=0,replace=True)
a9['new_region'] = 9
#df1.remove(a9,axis=0)

a10 = df1.sample(n=409,axis=0,replace=True)
a10['new_region'] = 10
#df1.remove(a10,axis=0)


df1 = pd.concat([a1,a2,a3,a4,a5,a6,a7,a8,a9,a10],ignore_index=True)

# %%
df1.new_region.value_counts()
# Out:
# 9     3604
# 1     2522
# 2      887
# 4      784
# 3      631
# 10     409
# 6      385
# 5      381
# 7      297
# 8      100
# Name: new_region, dtype: int64

# %%
df1.head()
# Out:
#    cusno  gender  age  region       id  product  price  quantity  amount  \
# 0   1660       1   20       9  2043144       20    352         5    1760
# 1   1809       1   80       1  2010403       10     61        11     671
# 2   1504       0   15       7  2018578       20    378         6    2268
# 3   1413       0   30      10  2041443       10     28        10     280
# 4   1097       0   57      10  2043296       10     75        18    1350
#
#         date day  age_c  new_region
# 0 2020-05-23   토     20           1
# 1 2020-05-25   월     60           1
# 2 2020-10-04   일     10           1
# 3 2020-09-24   목     30           1
# 4 2020-02-14   금     50           1

# %%
df1.drop('region',axis=1,inplace=True)
df1.head()
# Out:
#    cusno  gender  age       id  product  price  quantity  amount       date  \
# 0   1660       1   20  2043144       20    352         5    1760 2020-05-23
# 1   1809       1   80  2010403       10     61        11     671 2020-05-25
# 2   1504       0   15  2018578       20    378         6    2268 2020-10-04
# 3   1413       0   30  2041443       10     28        10     280 2020-09-24
# 4   1097       0   57  2043296       10     75        18    1350 2020-02-14
#
#   day  age_c  new_region
# 0   토     20           1
# 1   월     60           1
# 2   일     10           1
# 3   목     30           1
# 4   금     50           1

# %%
#월별(시즌) amount 가중치 부여
#1~3월 / 신학기 할인 → 중가 제품(product = 20) 가중치 부여
#5~9월 / 고가 제품(product = 30) 가중치 부여


condition20_1 = (df['product']==20) & (df.date.dt.month == 1)
df.loc[condition20_1,'']

conditon1_20 = (df['age_c'] == 20) & (df.date.dt.year == 2020)
conditon2_20 = (df['age_c'] == 30) & (df.date.dt.year == 2020)
conditon3_20 = (df['age_c'] == 40) & (df.date.dt.year == 2020)
conditon4_20 = (df['age_c'] == 50) & (df.date.dt.year == 2020)

conditon1_21 = (df['age_c'] == 20) & (df.date.dt.year == 2021)
conditon2_21 = (df['age_c'] == 30) & (df.date.dt.year == 2021)
conditon3_21 = (df['age_c'] == 40) & (df.date.dt.year == 2021)
conditon4_21 = (df['age_c'] == 50) & (df.date.dt.year == 2021)


df.loc[conditon1_20,'amount'] = df.amount *1.41
df.loc[conditon2_20,'amount'] = df.amount *2.56
df.loc[conditon3_20,'amount'] = df.amount *2.64
df.loc[conditon4_20,'amount'] = df.amount *2.02


df.loc[conditon1_21,'amount'] = df.amount *0.9
df.loc[conditon2_21,'amount'] = df.amount *1.63
df.loc[conditon3_21,'amount'] = df.amount *1.72
df.loc[conditon4_21,'amount'] = df.amount *1.36

# %%
# 가중치 sample
conditon1_20 = (df['age_c'] == 20) & (df.date.dt.year == 2020)
conditon2_20 = (df['age_c'] == 30) & (df.date.dt.year == 2020)
conditon3_20 = (df['age_c'] == 40) & (df.date.dt.year == 2020)
conditon4_20 = (df['age_c'] == 50) & (df.date.dt.year == 2020)

conditon1_21 = (df['age_c'] == 20) & (df.date.dt.year == 2021)
conditon2_21 = (df['age_c'] == 30) & (df.date.dt.year == 2021)
conditon3_21 = (df['age_c'] == 40) & (df.date.dt.year == 2021)
conditon4_21 = (df['age_c'] == 50) & (df.date.dt.year == 2021)


df.loc[conditon1_20,'amount'] = df.amount *1.41
df.loc[conditon2_20,'amount'] = df.amount *2.56
df.loc[conditon3_20,'amount'] = df.amount *2.64
df.loc[conditon4_20,'amount'] = df.amount *2.02


df.loc[conditon1_21,'amount'] = df.amount *0.9
df.loc[conditon2_21,'amount'] = df.amount *1.63
df.loc[conditon3_21,'amount'] = df.amount *1.72
df.loc[conditon4_21,'amount'] = df.amount *1.36

# %%
df.loc[conditon1_20,'amount'].value_counts()

# %%
df.loc[conditon1_21,'amount'].value_counts()
