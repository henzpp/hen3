# %%
import konlpy

# %%
# !pip install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xmltodict
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
url = 'http://apis.data.go.kr/1170000/law/lawSearchList.do?\
serviceKey=22Nn4Pf%2BappHSmLc8TsnR7KrSDh2oLZY%2BKUO%2Fk%2BAzsebJsWWxNqAafz3Y4c1t7SVy6SUTa2qvXNdbIwBzIvhrQ%3D%3D&\
target=law&query=*&numOfRows=10000&pageNo=1'

import requests
from bs4 import BeautifulSoup as bs
import xmltodict

# %%
req = requests.get(url).content
xmlobject = xmltodict.parse(req)
xmlobject['LawSearch']['law']
# Out:
# [{'@id': '1',
#   '법령일련번호': '232157',
#   '현행연혁코드': '현행',
#   '법령명한글': '10ㆍ27법난 피해자의 명예회복 등에 관한 법률',
#   '법령약칭명': '10ㆍ27법난법',
#   '법령ID': '010719',
#   '공포일자': '20210518',
#   '공포번호': '18146',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1371000',
#   '소관부처명': '문화체육관광부',
#   '법령구분명': '법률',
#   '시행일자': '20210518',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=232157&type=HTML&mobileYn=&efYd=20210518'},
#  {'@id': '2',
#   '법령일련번호': '235703',
#   '현행연혁코드': '현행',
#   '법령명한글': '10ㆍ27법난 피해자의 명예회복 등에 관한 법률 시행령',
#   '법령약칭명': '10ㆍ27법난법시행령',
#   '법령ID': '010831',
#   '공포일자': '20210929',
#   '공포번호': '32018',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1371000',
#   '소관부처명': '문화체육관광부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210929',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235703&type=HTML&mobileYn=&efYd=20210929'},
#  {'@id': '3',
#   '법령일련번호': '236231',
#   '현행연혁코드': '현행',
#   '법령명한글': '119구조ㆍ구급에 관한 법률',
#   '법령약칭명': '119법',
#   '법령ID': '011349',
#   '공포일자': '20211019',
#   '공포번호': '18487',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1661000',
#   '소관부처명': '소방청',
#   '법령구분명': '법률',
#   '시행일자': '20220120',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236231&type=HTML&mobileYn=&efYd=20220120'},
#  {'@id': '4',
#   '법령일련번호': '236155',
#   '현행연혁코드': '현행',
#   '법령명한글': '119구조ㆍ구급에 관한 법률 시행령',
#   '법령약칭명': '119법시행령',
#   '법령ID': '011452',
#   '공포일자': '20211019',
#   '공포번호': '32070',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1661000',
#   '소관부처명': '소방청',
#   '법령구분명': '대통령령',
#   '시행일자': '20220106',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236155&type=HTML&mobileYn=&efYd=20220106'},
#  {'@id': '5',
#   '법령일련번호': '243963',
#   '현행연혁코드': '현행',
#   '법령명한글': '119구조ㆍ구급에 관한 법률 시행규칙',
#   '법령약칭명': '119법시행규칙',
#   '법령ID': '011457',
#   '공포일자': '20220721',
#   '공포번호': '00345',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1661000',
#   '소관부처명': '소방청',
#   '법령구분명': '행정안전부령',
#   '시행일자': '20220721',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243963&type=HTML&mobileYn=&efYd=20220721'},
#  {'@id': '6',
#   '법령일련번호': '24144',
#   '현행연혁코드': '현행',
#   '법령명한글': '1945년이후종전의규정에의한학교졸업자자격인정령',
#   '법령약칭명': None,
#   '법령ID': '004546',
#   '공포일자': '19691204',
#   '공포번호': '04401',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '1342000',
#   '소관부처명': '교육부',
#   '법령구분명': '대통령령',
#   '시행일자': '19691204',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=24144&type=HTML&mobileYn=&efYd=19691204'},
#  {'@id': '7',
#   '법령일련번호': '206017',
#   '현행연혁코드': '현행',
#   '법령명한글': '1959년 12월 31일 이전에 퇴직한 군인의 퇴직급여금지급에 관한 특별법',
#   '법령약칭명': '1959이전군퇴직금법',
#   '법령ID': '009678',
#   '공포일자': '20181224',
#   '공포번호': '16029',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20190625',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=206017&type=HTML&mobileYn=&efYd=20190625'},
#  {'@id': '8',
#   '법령일련번호': '208133',
#   '현행연혁코드': '현행',
#   '법령명한글': '1959년 12월 31일 이전에 퇴직한 군인의 퇴직급여금지급에 관한 특별법 시행령',
#   '법령약칭명': '1959이전군퇴직금법시행령',
#   '법령ID': '009990',
#   '공포일자': '20190325',
#   '공포번호': '29637',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20190325',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=208133&type=HTML&mobileYn=&efYd=20190325'},
#  {'@id': '9',
#   '법령일련번호': '3274',
#   '현행연혁코드': '현행',
#   '법령명한글': '1980년해직공무원의보상등에관한특별조치법',
#   '법령약칭명': '1980해직자보상법',
#   '법령ID': '001348',
#   '공포일자': '19890329',
#   '공포번호': '04101',
#   '제개정구분명': '제정',
#   '소관부처코드': '1760000',
#   '소관부처명': '인사혁신처',
#   '법령구분명': '법률',
#   '시행일자': '19890329',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=3274&type=HTML&mobileYn=&efYd=19890329'},
#  {'@id': '10',
#   '법령일련번호': '204611',
#   '현행연혁코드': '현행',
#   '법령명한글': '1980년해직공무원의보상등에관한특별조치법시행령',
#   '법령약칭명': '1980해직자보상법시행령',
#   '법령ID': '004549',
#   '공포일자': '20180918',
#   '공포번호': '29181',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1760000',
#   '소관부처명': '인사혁신처',
#   '법령구분명': '대통령령',
#   '시행일자': '20180921',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=204611&type=HTML&mobileYn=&efYd=20180921'},
#  {'@id': '11',
#   '법령일련번호': '214477',
#   '현행연혁코드': '현행',
#   '법령명한글': '1인 창조기업 육성에 관한 법률',
#   '법령약칭명': '1인창조기업법',
#   '법령ID': '011370',
#   '공포일자': '20200218',
#   '공포번호': '17037',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1421000',
#   '소관부처명': '중소벤처기업부',
#   '법령구분명': '법률',
#   '시행일자': '20210219',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=214477&type=HTML&mobileYn=&efYd=20210219'},
#  {'@id': '12',
#   '법령일련번호': '230831',
#   '현행연혁코드': '현행',
#   '법령명한글': '1인 창조기업 육성에 관한 법률 시행령',
#   '법령약칭명': '1인창조기업법시행령',
#   '법령ID': '011474',
#   '공포일자': '20210406',
#   '공포번호': '31611',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1421000',
#   '소관부처명': '중소벤처기업부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210408',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=230831&type=HTML&mobileYn=&efYd=20210408'},
#  {'@id': '13',
#   '법령일련번호': '233105',
#   '현행연혁코드': '현행',
#   '법령명한글': '2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법',
#   '법령약칭명': '평창올림픽법',
#   '법령ID': '011532',
#   '공포일자': '20210615',
#   '공포번호': '18284',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1371000',
#   '소관부처명': '문화체육관광부',
#   '법령구분명': '법률',
#   '시행일자': '20220616',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=233105&type=HTML&mobileYn=&efYd=20220616'},
#  {'@id': '14',
#   '법령일련번호': '239581',
#   '현행연혁코드': '현행',
#   '법령명한글': '2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법 시행령',
#   '법령약칭명': '평창올림픽법시행령',
#   '법령ID': '011679',
#   '공포일자': '20220121',
#   '공포번호': '32352',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1371000',
#   '소관부처명': '문화체육관광부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220121',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=239581&type=HTML&mobileYn=&efYd=20220121'},
#  {'@id': '15',
#   '법령일련번호': '205822',
#   '현행연혁코드': '현행',
#   '법령명한글': '2023 새만금 세계스카우트잼버리 지원 특별법',
#   '법령약칭명': '새만금세계잼버리법',
#   '법령ID': '013210',
#   '공포일자': '20181218',
#   '공포번호': '15984',
#   '제개정구분명': '제정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '법률',
#   '시행일자': '20191219',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=205822&type=HTML&mobileYn=&efYd=20191219'},
#  {'@id': '16',
#   '법령일련번호': '212307',
#   '현행연혁코드': '현행',
#   '법령명한글': '2023 새만금 세계스카우트잼버리 지원 특별법 시행령',
#   '법령약칭명': '새만금세계잼버리법시행령',
#   '법령ID': '013626',
#   '공포일자': '20191210',
#   '공포번호': '30241',
#   '제개정구분명': '제정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '대통령령',
#   '시행일자': '20191219',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=212307&type=HTML&mobileYn=&efYd=20191219'},
#  {'@id': '17',
#   '법령일련번호': '234657',
#   '현행연혁코드': '현행',
#   '법령명한글': '2023 순천만국제정원박람회 지원 및 사후활용에 관한 특별법',
#   '법령약칭명': '순천만정원박람회법',
#   '법령ID': '014137',
#   '공포일자': '20210817',
#   '공포번호': '18399',
#   '제개정구분명': '제정',
#   '소관부처코드': '1400000',
#   '소관부처명': '산림청',
#   '법령구분명': '법률',
#   '시행일자': '20220218',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234657&type=HTML&mobileYn=&efYd=20220218'},
#  {'@id': '18',
#   '법령일련번호': '240347',
#   '현행연혁코드': '현행',
#   '법령명한글': '2023 순천만국제정원박람회 지원 및 사후활용에 관한 특별법 시행령',
#   '법령약칭명': '순천만정원박람회법시행령',
#   '법령ID': '014243',
#   '공포일자': '20220215',
#   '공포번호': '32436',
#   '제개정구분명': '제정',
#   '소관부처코드': '1400000',
#   '소관부처명': '산림청',
#   '법령구분명': '대통령령',
#   '시행일자': '20220218',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=240347&type=HTML&mobileYn=&efYd=20220218'},
#  {'@id': '19',
#   '법령일련번호': '243787',
#   '현행연혁코드': '현행',
#   '법령명한글': '2030 부산세계박람회 유치위원회의 설치 및 운영에 관한 규정',
#   '법령약칭명': None,
#   '법령ID': '014308',
#   '공포일자': '20220708',
#   '공포번호': '32783',
#   '제개정구분명': '제정',
#   '소관부처코드': '1450000',
#   '소관부처명': '산업통상자원부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220708',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243787&type=HTML&mobileYn=&efYd=20220708'},
#  {'@id': '20',
#   '법령일련번호': '231363',
#   '현행연혁코드': '현행',
#   '법령명한글': '30개월 이상 복무한 상등병 만기전역자의 특별진급을 위한 특별법',
#   '법령약칭명': '상등병전역자특별진급법',
#   '법령ID': '014061',
#   '공포일자': '20210413',
#   '공포번호': '17991',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231363&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '21',
#   '법령일련번호': '236011',
#   '현행연혁코드': '현행',
#   '법령명한글': '30개월 이상 복무한 상등병 만기전역자의 특별진급을 위한 특별법 시행령',
#   '법령약칭명': '상등병전역자특별진급법시행령',
#   '법령ID': '014165',
#   '공포일자': '20211014',
#   '공포번호': '32036',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236011&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '22',
#   '법령일련번호': '233957',
#   '현행연혁코드': '현행',
#   '법령명한글': '3ㆍ15의거 참여자의 명예회복 등에 관한 법률',
#   '법령약칭명': '3ㆍ15의거법',
#   '법령ID': '014119',
#   '공포일자': '20210720',
#   '공포번호': '18301',
#   '제개정구분명': '제정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '법률',
#   '시행일자': '20220121',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=233957&type=HTML&mobileYn=&efYd=20220121'},
#  {'@id': '23',
#   '법령일련번호': '239577',
#   '현행연혁코드': '현행',
#   '법령명한글': '3ㆍ15의거 참여자의 명예회복 등에 관한 법률 시행령',
#   '법령약칭명': '3ㆍ15의거법시행령',
#   '법령ID': '014229',
#   '공포일자': '20220121',
#   '공포번호': '32350',
#   '제개정구분명': '제정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220121',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=239577&type=HTML&mobileYn=&efYd=20220121'},
#  {'@id': '24',
#   '법령일련번호': '162682',
#   '현행연혁코드': '현행',
#   '법령명한글': '4ㆍ16세월호참사 진상규명 및 안전사회 건설 등을 위한 특별법',
#   '법령약칭명': '세월호진상규명법',
#   '법령ID': '012159',
#   '공포일자': '20141119',
#   '공포번호': '12843',
#   '제개정구분명': '제정',
#   '소관부처코드': '1192000',
#   '소관부처명': '해양수산부',
#   '법령구분명': '법률',
#   '시행일자': '20150101',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=162682&type=HTML&mobileYn=&efYd=20150101'},
#  {'@id': '25',
#   '법령일련번호': '195782',
#   '현행연혁코드': '현행',
#   '법령명한글': '4ㆍ16세월호참사 진상규명 및 안전사회 건설 등을 위한 특별법 시행령',
#   '법령약칭명': '세월호진상규명법시행령',
#   '법령ID': '012290',
#   '공포일자': '20170726',
#   '공포번호': '28211',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1192000',
#   '소관부처명': '해양수산부',
#   '법령구분명': '대통령령',
#   '시행일자': '20170726',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=195782&type=HTML&mobileYn=&efYd=20170726'},
#  {'@id': '26',
#   '법령일련번호': '243107',
#   '현행연혁코드': '현행',
#   '법령명한글': '4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법',
#   '법령약칭명': '세월호피해지원법',
#   '법령ID': '012245',
#   '공포일자': '20220610',
#   '공포번호': '18954',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1092000 1192000',
#   '소관부처명': '국무조정실,해양수산부',
#   '법령구분명': '법률',
#   '시행일자': '20220610',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243107&type=HTML&mobileYn=&efYd=20220610'},
#  {'@id': '27',
#   '법령일련번호': '227113',
#   '현행연혁코드': '현행',
#   '법령명한글': '4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법 시행령',
#   '법령약칭명': '세월호피해지원법시행령',
#   '법령ID': '012272',
#   '공포일자': '20210105',
#   '공포번호': '31380',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1092000 1192000',
#   '소관부처명': '국무조정실,해양수산부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210105',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=227113&type=HTML&mobileYn=&efYd=20210105'},
#  {'@id': '28',
#   '법령일련번호': '228675',
#   '현행연혁코드': '현행',
#   '법령명한글': '4차산업혁명위원회의 설치 및 운영에 관한 규정',
#   '법령약칭명': None,
#   '법령ID': '012976',
#   '공포일자': '20210112',
#   '공포번호': '31385',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1721000',
#   '소관부처명': '과학기술정보통신부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210112',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=228675&type=HTML&mobileYn=&efYd=20210112'},
#  {'@id': '29',
#   '법령일련번호': '234839',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주유공자예우 및 단체설립에 관한 법률',
#   '법령약칭명': '5ㆍ18유공자법',
#   '법령ID': '009289',
#   '공포일자': '20210817',
#   '공포번호': '18439',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1180000',
#   '소관부처명': '국가보훈처',
#   '법령구분명': '법률',
#   '시행일자': '20220218',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234839&type=HTML&mobileYn=&efYd=20220218'},
#  {'@id': '30',
#   '법령일련번호': '242425',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주유공자예우 및 단체설립에 관한 법률 시행령',
#   '법령약칭명': '5ㆍ18유공자법시행령',
#   '법령ID': '009339',
#   '공포일자': '20220509',
#   '공포번호': '32645',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1180000',
#   '소관부처명': '국가보훈처',
#   '법령구분명': '대통령령',
#   '시행일자': '20220509',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242425&type=HTML&mobileYn=&efYd=20220509'},
#  {'@id': '31',
#   '법령일련번호': '243351',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주유공자예우 및 단체설립에 관한 법률 시행규칙',
#   '법령약칭명': '5ㆍ18유공자법시행규칙',
#   '법령ID': '009381',
#   '공포일자': '20220620',
#   '공포번호': '01811',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1180000',
#   '소관부처명': '국가보훈처',
#   '법령구분명': '총리령',
#   '시행일자': '20220620',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243351&type=HTML&mobileYn=&efYd=20220620'},
#  {'@id': '32',
#   '법령일련번호': '232623',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주화운동 관련자 보상 등에 관한 법률',
#   '법령약칭명': '5ㆍ18보상법',
#   '법령ID': '001234',
#   '공포일자': '20210608',
#   '공포번호': '18203',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '법률',
#   '시행일자': '20211209',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=232623&type=HTML&mobileYn=&efYd=20211209'},
#  {'@id': '33',
#   '법령일련번호': '237341',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주화운동 관련자 보상 등에 관한 법률 시행령',
#   '법령약칭명': '5ㆍ18보상법시행령',
#   '법령ID': '002543',
#   '공포일자': '20211207',
#   '공포번호': '32181',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20211209',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=237341&type=HTML&mobileYn=&efYd=20211209'},
#  {'@id': '34',
#   '법령일련번호': '235549',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주화운동 등에 관한 특별법',
#   '법령약칭명': '5ㆍ18민주화운동법',
#   '법령ID': '001159',
#   '공포일자': '20210924',
#   '공포번호': '18465',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1270000 1290000',
#   '소관부처명': '국방부,법무부',
#   '법령구분명': '법률',
#   '시행일자': '20220701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235549&type=HTML&mobileYn=&efYd=20220701'},
#  {'@id': '35',
#   '법령일련번호': '228259',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주화운동 진상규명을 위한 특별법',
#   '법령약칭명': '5ㆍ18진상규명법',
#   '법령ID': '013091',
#   '공포일자': '20210105',
#   '공포번호': '17886',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1075000',
#   '소관부처명': '5.18민주화운동진상규명조사위원회',
#   '법령구분명': '법률',
#   '시행일자': '20210206',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=228259&type=HTML&mobileYn=&efYd=20210206'},
#  {'@id': '36',
#   '법령일련번호': '240731',
#   '현행연혁코드': '현행',
#   '법령명한글': '5ㆍ18민주화운동 진상규명을 위한 특별법 시행령',
#   '법령약칭명': None,
#   '법령ID': '013166',
#   '공포일자': '20220222',
#   '공포번호': '32460',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1075000',
#   '소관부처명': '5.18민주화운동진상규명조사위원회',
#   '법령구분명': '대통령령',
#   '시행일자': '20220222',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=240731&type=HTML&mobileYn=&efYd=20220222'},
#  {'@id': '37',
#   '법령일련번호': '231365',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25 전사자유해의 발굴 등에 관한 법률',
#   '법령약칭명': '6ㆍ25전사자발굴법',
#   '법령ID': '010716',
#   '공포일자': '20210413',
#   '공포번호': '17992',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231365&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '38',
#   '법령일련번호': '236057',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25 전사자유해의 발굴 등에 관한 법률 시행령',
#   '법령약칭명': '6ㆍ25전사자발굴법시행령',
#   '법령ID': '010791',
#   '공포일자': '20211014',
#   '공포번호': '32041',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236057&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '39',
#   '법령일련번호': '204768',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률',
#   '법령약칭명': '6ㆍ25납북자법',
#   '법령ID': '011176',
#   '공포일자': '20181016',
#   '공포번호': '15790',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1250000',
#   '소관부처명': '통일부',
#   '법령구분명': '법률',
#   '시행일자': '20181016',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=204768&type=HTML&mobileYn=&efYd=20181016'},
#  {'@id': '40',
#   '법령일련번호': '195536',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률 시행령',
#   '법령약칭명': '6ㆍ25납북자법시행령',
#   '법령ID': '011285',
#   '공포일자': '20170726',
#   '공포번호': '28211',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1250000',
#   '소관부처명': '통일부',
#   '법령구분명': '대통령령',
#   '시행일자': '20170726',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=195536&type=HTML&mobileYn=&efYd=20170726'},
#  {'@id': '41',
#   '법령일련번호': '108667',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률에 의한 가족관계등록사무처리규칙',
#   '법령약칭명': None,
#   '법령ID': '011302',
#   '공포일자': '20101104',
#   '공포번호': '02307',
#   '제개정구분명': '제정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20101104',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=108667&type=HTML&mobileYn=&efYd=20101104'},
#  {'@id': '42',
#   '법령일련번호': '238801',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 무공훈장 수여 등에 관한 법률',
#   '법령약칭명': '6ㆍ25무공훈장법',
#   '법령ID': '013468',
#   '공포일자': '20220104',
#   '공포번호': '18679',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20220104',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=238801&type=HTML&mobileYn=&efYd=20220104'},
#  {'@id': '43',
#   '법령일련번호': '210003',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 무공훈장 수여 등에 관한 법률 시행령',
#   '법령약칭명': '6ㆍ25무공훈장법시행령',
#   '법령ID': '013528',
#   '공포일자': '20190723',
#   '공포번호': '29993',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20190724',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=210003&type=HTML&mobileYn=&efYd=20190724'},
#  {'@id': '44',
#   '법령일련번호': '231367',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률',
#   '법령약칭명': '6ㆍ25비정규군보상법',
#   '법령ID': '014062',
#   '공포일자': '20210413',
#   '공포번호': '17993',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231367&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '45',
#   '법령일련번호': '236013',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률 시행령',
#   '법령약칭명': '6ㆍ25비정규군보상법시행령',
#   '법령ID': '014166',
#   '공포일자': '20211014',
#   '공포번호': '32037',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236013&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '46',
#   '법령일련번호': '235863',
#   '현행연혁코드': '현행',
#   '법령명한글': '6ㆍ25전쟁 정전60주년 기념 호국영웅기장 수여규칙',
#   '법령약칭명': None,
#   '법령ID': '011890',
#   '공포일자': '20210927',
#   '공포번호': '01733',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1180000',
#   '소관부처명': '국가보훈처',
#   '법령구분명': '총리령',
#   '시행일자': '20210927',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235863&type=HTML&mobileYn=&efYd=20210927'},
#  {'@id': '47',
#   '법령일련번호': '230203',
#   '현행연혁코드': '현행',
#   '법령명한글': '가덕도신공항 건설을 위한 특별법',
#   '법령약칭명': '가덕도신공항법',
#   '법령ID': '014035',
#   '공포일자': '20210316',
#   '공포번호': '17938',
#   '제개정구분명': '제정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '법률',
#   '시행일자': '20210917',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=230203&type=HTML&mobileYn=&efYd=20210917'},
#  {'@id': '48',
#   '법령일련번호': '235431',
#   '현행연혁코드': '현행',
#   '법령명한글': '가덕도신공항 건설을 위한 특별법 시행령',
#   '법령약칭명': '가덕도신공항법시행령',
#   '법령ID': '014145',
#   '공포일자': '20210914',
#   '공포번호': '31987',
#   '제개정구분명': '제정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210917',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235431&type=HTML&mobileYn=&efYd=20210917'},
#  {'@id': '49',
#   '법령일련번호': '235695',
#   '현행연혁코드': '현행',
#   '법령명한글': '가덕도신공항 건설을 위한 특별법 시행규칙',
#   '법령약칭명': '가덕도신공항법시행규칙',
#   '법령ID': '014155',
#   '공포일자': '20210917',
#   '공포번호': '00886',
#   '제개정구분명': '제정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '국토교통부령',
#   '시행일자': '20210917',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235695&type=HTML&mobileYn=&efYd=20210917'},
#  {'@id': '50',
#   '법령일련번호': '188538',
#   '현행연혁코드': '현행',
#   '법령명한글': '가등기담보 등에 관한 법률',
#   '법령약칭명': '가등기담보법',
#   '법령ID': '001257',
#   '공포일자': '20161227',
#   '공포번호': '14474',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '법률',
#   '시행일자': '20170328',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=188538&type=HTML&mobileYn=&efYd=20170328'},
#  {'@id': '51',
#   '법령일련번호': '238849',
#   '현행연혁코드': '현행',
#   '법령명한글': '가맹사업거래의 공정화에 관한 법률',
#   '법령약칭명': '체인점 가맹사업법',
#   '법령ID': '009367',
#   '공포일자': '20220104',
#   '공포번호': '18709',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1130000',
#   '소관부처명': '공정거래위원회',
#   '법령구분명': '법률',
#   '시행일자': '20220705',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=238849&type=HTML&mobileYn=&efYd=20220705'},
#  {'@id': '52',
#   '법령일련번호': '242825',
#   '현행연혁코드': '현행',
#   '법령명한글': '가맹사업거래의 공정화에 관한 법률 시행령',
#   '법령약칭명': '체인점 가맹사업법시행령',
#   '법령ID': '009369',
#   '공포일자': '20220607',
#   '공포번호': '32680',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1130000',
#   '소관부처명': '공정거래위원회',
#   '법령구분명': '대통령령',
#   '시행일자': '20220705',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242825&type=HTML&mobileYn=&efYd=20220705'},
#  {'@id': '53',
#   '법령일련번호': '232893',
#   '현행연혁코드': '현행',
#   '법령명한글': '가맹사업 진흥에 관한 법률',
#   '법령약칭명': '체인점 가맹사업진흥법',
#   '법령ID': '010593',
#   '공포일자': '20210615',
#   '공포번호': '18267',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1450000',
#   '소관부처명': '산업통상자원부',
#   '법령구분명': '법률',
#   '시행일자': '20211216',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=232893&type=HTML&mobileYn=&efYd=20211216'},
#  {'@id': '54',
#   '법령일련번호': '208610',
#   '현행연혁코드': '현행',
#   '법령명한글': '가맹사업 진흥에 관한 법률 시행령',
#   '법령약칭명': '체인점 가맹사업진흥법시행령',
#   '법령ID': '010786',
#   '공포일자': '20190430',
#   '공포번호': '29721',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1450000',
#   '소관부처명': '산업통상자원부',
#   '법령구분명': '대통령령',
#   '시행일자': '20190430',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=208610&type=HTML&mobileYn=&efYd=20190430'},
#  {'@id': '55',
#   '법령일련번호': '232959',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사근로자의 고용개선 등에 관한 법률',
#   '법령약칭명': '가사근로자법',
#   '법령ID': '014099',
#   '공포일자': '20210615',
#   '공포번호': '18285',
#   '제개정구분명': '제정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '법률',
#   '시행일자': '20220616',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=232959&type=HTML&mobileYn=&efYd=20220616'},
#  {'@id': '56',
#   '법령일련번호': '242699',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사근로자의 고용개선 등에 관한 법률 시행령',
#   '법령약칭명': '가사근로자법시행령',
#   '법령ID': '014286',
#   '공포일자': '20220531',
#   '공포번호': '32659',
#   '제개정구분명': '제정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220616',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242699&type=HTML&mobileYn=&efYd=20220616'},
#  {'@id': '57',
#   '법령일련번호': '243269',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사근로자의 고용개선 등에 관한 법률 시행규칙',
#   '법령약칭명': '가사근로자법시행규칙',
#   '법령ID': '014297',
#   '공포일자': '20220609',
#   '공포번호': '00354',
#   '제개정구분명': '제정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '고용노동부령',
#   '시행일자': '20220616',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243269&type=HTML&mobileYn=&efYd=20220616'},
#  {'@id': '58',
#   '법령일련번호': '210085',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사소송규칙',
#   '법령약칭명': None,
#   '법령ID': '005694',
#   '공포일자': '20190802',
#   '공포번호': '02856',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20190802',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=210085&type=HTML&mobileYn=&efYd=20190802'},
#  {'@id': '59',
#   '법령일련번호': '228887',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사소송법',
#   '법령약칭명': None,
#   '법령ID': '001206',
#   '공포일자': '20210126',
#   '공포번호': '17905',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '법률',
#   '시행일자': '20210126',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=228887&type=HTML&mobileYn=&efYd=20210126'},
#  {'@id': '60',
#   '법령일련번호': '181255',
#   '현행연혁코드': '현행',
#   '법령명한글': '가사소송수수료규칙',
#   '법령약칭명': None,
#   '법령ID': '005695',
#   '공포일자': '20160219',
#   '공포번호': '02639',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20160701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=181255&type=HTML&mobileYn=&efYd=20160701'},
#  {'@id': '61',
#   '법령일련번호': '243607',
#   '현행연혁코드': '현행',
#   '법령명한글': '가석방자관리규정',
#   '법령약칭명': None,
#   '법령ID': '002049',
#   '공포일자': '20220630',
#   '공포번호': '32737',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243607&type=HTML&mobileYn=&efYd=20220701'},
#  {'@id': '62',
#   '법령일련번호': '215909',
#   '현행연혁코드': '현행',
#   '법령명한글': '가습기살균제 피해구제를 위한 특별법',
#   '법령약칭명': '가습기살균제피해구제법',
#   '법령ID': '012804',
#   '공포일자': '20200324',
#   '공포번호': '17102',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '법률',
#   '시행일자': '20200925',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=215909&type=HTML&mobileYn=&efYd=20200925'},
#  {'@id': '63',
#   '법령일련번호': '229487',
#   '현행연혁코드': '현행',
#   '법령명한글': '가습기살균제 피해구제를 위한 특별법 시행령',
#   '법령약칭명': None,
#   '법령ID': '012969',
#   '공포일자': '20210217',
#   '공포번호': '31453',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210217',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=229487&type=HTML&mobileYn=&efYd=20210217'},
#  {'@id': '64',
#   '법령일련번호': '221925',
#   '현행연혁코드': '현행',
#   '법령명한글': '가습기살균제 피해구제를 위한 특별법 시행규칙',
#   '법령약칭명': None,
#   '법령ID': '012971',
#   '공포일자': '20200925',
#   '공포번호': '00882',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '환경부령',
#   '시행일자': '20200925',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=221925&type=HTML&mobileYn=&efYd=20200925'},
#  {'@id': '65',
#   '법령일련번호': '241059',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정보호심판규칙',
#   '법령약칭명': None,
#   '법령ID': '005698',
#   '공포일자': '20220225',
#   '공포번호': '03038',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20220225',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241059&type=HTML&mobileYn=&efYd=20220225'},
#  {'@id': '66',
#   '법령일련번호': '219133',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정폭력방지 및 피해자보호 등에 관한 법률',
#   '법령약칭명': '가정폭력방지법',
#   '법령ID': '000182',
#   '공포일자': '20200609',
#   '공포번호': '17437',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '법률',
#   '시행일자': '20200609',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=219133&type=HTML&mobileYn=&efYd=20200609'},
#  {'@id': '67',
#   '법령일련번호': '190383',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정폭력방지 및 피해자보호 등에 관한 법률 시행령',
#   '법령약칭명': '가정폭력방지법시행령',
#   '법령ID': '002053',
#   '공포일자': '20161230',
#   '공포번호': '27751',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '대통령령',
#   '시행일자': '20170101',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=190383&type=HTML&mobileYn=&efYd=20170101'},
#  {'@id': '68',
#   '법령일련번호': '231097',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정폭력방지 및 피해자보호 등에 관한 법률 시행규칙',
#   '법령약칭명': '가정폭력방지법시행규칙',
#   '법령ID': '006120',
#   '공포일자': '20210402',
#   '공포번호': '00163',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '여성가족부령',
#   '시행일자': '20210402',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231097&type=HTML&mobileYn=&efYd=20210402'},
#  {'@id': '69',
#   '법령일련번호': '222419',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정폭력범죄의 처벌 등에 관한 특례법',
#   '법령약칭명': '가정폭력처벌법',
#   '법령ID': '001132',
#   '공포일자': '20201020',
#   '공포번호': '17499',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '법률',
#   '시행일자': '20210121',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=222419&type=HTML&mobileYn=&efYd=20210121'},
#  {'@id': '70',
#   '법령일련번호': '172201',
#   '현행연혁코드': '현행',
#   '법령명한글': '가정폭력범죄의 처벌 등에 관한 특례법 시행령',
#   '법령약칭명': '가정폭력처벌법시행령',
#   '법령ID': '012308',
#   '공포일자': '20150622',
#   '공포번호': '26325',
#   '제개정구분명': '제정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '대통령령',
#   '시행일자': '20160101',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=172201&type=HTML&mobileYn=&efYd=20160101'},
#  {'@id': '71',
#   '법령일련번호': '243597',
#   '현행연혁코드': '현행',
#   '법령명한글': '가족관계의 등록 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '010569',
#   '공포일자': '20220630',
#   '공포번호': '03062',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20220630',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243597&type=HTML&mobileYn=&efYd=20220630'},
#  {'@id': '72',
#   '법령일련번호': '238211',
#   '현행연혁코드': '현행',
#   '법령명한글': '가족관계의 등록 등에 관한 법률',
#   '법령약칭명': '가족관계등록법',
#   '법령ID': '010444',
#   '공포일자': '20211228',
#   '공포번호': '18651',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1270000',
#   '소관부처명': '법무부',
#   '법령구분명': '법률',
#   '시행일자': '20220101',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=238211&type=HTML&mobileYn=&efYd=20220101'},
#  {'@id': '73',
#   '법령일련번호': '219135',
#   '현행연혁코드': '현행',
#   '법령명한글': '가족친화 사회환경의 조성 촉진에 관한 법률',
#   '법령약칭명': '가족친화법',
#   '법령ID': '010583',
#   '공포일자': '20200609',
#   '공포번호': '17438',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '법률',
#   '시행일자': '20201210',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=219135&type=HTML&mobileYn=&efYd=20201210'},
#  {'@id': '74',
#   '법령일련번호': '220557',
#   '현행연혁코드': '현행',
#   '법령명한글': '가족친화 사회환경의 조성 촉진에 관한 법률 시행령',
#   '법령약칭명': '가족친화법시행령',
#   '법령ID': '010770',
#   '공포일자': '20200804',
#   '공포번호': '30895',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '대통령령',
#   '시행일자': '20200805',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=220557&type=HTML&mobileYn=&efYd=20200805'},
#  {'@id': '75',
#   '법령일련번호': '176054',
#   '현행연혁코드': '현행',
#   '법령명한글': '가족친화 사회환경의 조성 촉진에 관한 법률 시행규칙',
#   '법령약칭명': '가족친화법시행규칙',
#   '법령ID': '010774',
#   '공포일자': '20151104',
#   '공포번호': '00080',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1383000',
#   '소관부처명': '여성가족부',
#   '법령구분명': '여성가족부령',
#   '시행일자': '20151104',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=176054&type=HTML&mobileYn=&efYd=20151104'},
#  {'@id': '76',
#   '법령일련번호': '218171',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축 및 축산물 이력관리에 관한 법률',
#   '법령약칭명': '축산물이력법',
#   '법령ID': '010599',
#   '공포일자': '20200526',
#   '공포번호': '17324',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '법률',
#   '시행일자': '20201127',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=218171&type=HTML&mobileYn=&efYd=20201127'},
#  {'@id': '77',
#   '법령일련번호': '212349',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축 및 축산물 이력관리에 관한 법률 시행령',
#   '법령약칭명': '축산물이력법시행령',
#   '법령ID': '010875',
#   '공포일자': '20191217',
#   '공포번호': '30247',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '대통령령',
#   '시행일자': '20200101',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=212349&type=HTML&mobileYn=&efYd=20200101'},
#  {'@id': '78',
#   '법령일련번호': '239955',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축 및 축산물 이력관리에 관한 법률 시행규칙',
#   '법령약칭명': '축산물이력법시행규칙',
#   '법령ID': '010884',
#   '공포일자': '20220125',
#   '공포번호': '00517',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '농림축산식품부령',
#   '시행일자': '20220125',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=239955&type=HTML&mobileYn=&efYd=20220125'},
#  {'@id': '79',
#   '법령일련번호': '231457',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축분뇨의 관리 및 이용에 관한 법률',
#   '법령약칭명': '가축분뇨법',
#   '법령ID': '010297',
#   '공포일자': '20210413',
#   '공포번호': '18027',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '법률',
#   '시행일자': '20220414',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231457&type=HTML&mobileYn=&efYd=20220414'},
#  {'@id': '80',
#   '법령일련번호': '243133',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축분뇨의 관리 및 이용에 관한 법률 시행령',
#   '법령약칭명': '가축분뇨법시행령',
#   '법령ID': '010527',
#   '공포일자': '20220614',
#   '공포번호': '32697',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220616',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243133&type=HTML&mobileYn=&efYd=20220616'},
#  {'@id': '81',
#   '법령일련번호': '241875',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축분뇨의 관리 및 이용에 관한 법률 시행규칙',
#   '법령약칭명': '가축분뇨법시행규칙',
#   '법령ID': '010532',
#   '공포일자': '20220414',
#   '공포번호': '00982',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1480000',
#   '소관부처명': '환경부',
#   '법령구분명': '환경부령',
#   '시행일자': '20220414',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241875&type=HTML&mobileYn=&efYd=20220414'},
#  {'@id': '82',
#   '법령일련번호': '210393',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축분뇨의 자원화 및 이용 촉진에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '010566',
#   '공포일자': '20190826',
#   '공포번호': '00391',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '농림축산식품부령',
#   '시행일자': '20190826',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=210393&type=HTML&mobileYn=&efYd=20190826'},
#  {'@id': '83',
#   '법령일련번호': '236951',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축전염병 예방법',
#   '법령약칭명': None,
#   '법령ID': '001504',
#   '공포일자': '20211130',
#   '공포번호': '18524',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '법률',
#   '시행일자': '20211130',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236951&type=HTML&mobileYn=&efYd=20211130'},
#  {'@id': '84',
#   '법령일련번호': '235885',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축전염병 예방법 시행령',
#   '법령약칭명': None,
#   '법령ID': '002058',
#   '공포일자': '20211005',
#   '공포번호': '32023',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '대통령령',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=235885&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '85',
#   '법령일련번호': '236323',
#   '현행연혁코드': '현행',
#   '법령명한글': '가축전염병 예방법 시행규칙',
#   '법령약칭명': None,
#   '법령ID': '006128',
#   '공포일자': '20211014',
#   '공포번호': '00498',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '농림축산식품부령',
#   '시행일자': '20211014',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=236323&type=HTML&mobileYn=&efYd=20211014'},
#  {'@id': '86',
#   '법령일련번호': '241071',
#   '현행연혁코드': '현행',
#   '법령명한글': '각급 법원에 배치할 판사의 수에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '005699',
#   '공포일자': '20220225',
#   '공포번호': '03045',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20220225',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241071&type=HTML&mobileYn=&efYd=20220225'},
#  {'@id': '87',
#   '법령일련번호': '151985',
#   '현행연혁코드': '현행',
#   '법령명한글': '각급 법원의 설치와 관할구역에 관한 법률',
#   '법령약칭명': '법원설치법',
#   '법령ID': '001709',
#   '공포일자': '20140318',
#   '공포번호': '12419',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '법률',
#   '시행일자': '20190301',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=151985&type=HTML&mobileYn=&efYd=20190301'},
#  {'@id': '88',
#   '법령일련번호': '166366',
#   '현행연혁코드': '현행',
#   '법령명한글': '각급 법원 판사 정원법',
#   '법령약칭명': '판사정원법',
#   '법령ID': '001300',
#   '공포일자': '20141231',
#   '공포번호': '12951',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '법률',
#   '시행일자': '20141231',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=166366&type=HTML&mobileYn=&efYd=20141231'},
#  {'@id': '89',
#   '법령일련번호': '35917',
#   '현행연혁코드': '현행',
#   '법령명한글': '각급선거관리위원회회의규칙',
#   '법령약칭명': None,
#   '법령ID': '006032',
#   '공포일자': '19820122',
#   '공포번호': '00052',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '9760000',
#   '소관부처명': '중앙선거관리위원회',
#   '법령구분명': '중앙선거관리위원회규칙',
#   '시행일자': '19820122',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=35917&type=HTML&mobileYn=&efYd=19820122'},
#  {'@id': '90',
#   '법령일련번호': '214023',
#   '현행연혁코드': '현행',
#   '법령명한글': '각병과사병의군사경찰직무보조에관한규정',
#   '법령약칭명': None,
#   '법령ID': '002061',
#   '공포일자': '20200204',
#   '공포번호': '30384',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20200204',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=214023&type=HTML&mobileYn=&efYd=20200204'},
#  {'@id': '91',
#   '법령일련번호': '224113',
#   '현행연혁코드': '현행',
#   '법령명한글': '각종 기념일 등에 관한 규정',
#   '법령약칭명': '기념일규정',
#   '법령ID': '002065',
#   '공포일자': '20201215',
#   '공포번호': '31264',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20201215',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=224113&type=HTML&mobileYn=&efYd=20201215'},
#  {'@id': '92',
#   '법령일련번호': '52364',
#   '현행연혁코드': '현행',
#   '법령명한글': '각종분쟁조정위원회등의조정조서등에대한집행문부여에관한규칙',
#   '법령약칭명': None,
#   '법령ID': '005701',
#   '공포일자': '20020628',
#   '공포번호': '01768',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '9740000',
#   '소관부처명': '대법원',
#   '법령구분명': '대법원규칙',
#   '시행일자': '20020701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=52364&type=HTML&mobileYn=&efYd=20020701'},
#  {'@id': '93',
#   '법령일련번호': '228491',
#   '현행연혁코드': '현행',
#   '법령명한글': '간선급행버스체계의 건설 및 운영에 관한 특별법',
#   '법령약칭명': '간선급행버스법',
#   '법령ID': '012071',
#   '공포일자': '20210112',
#   '공포번호': '17893',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '법률',
#   '시행일자': '20220113',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=228491&type=HTML&mobileYn=&efYd=20220113'},
#  {'@id': '94',
#   '법령일련번호': '231641',
#   '현행연혁코드': '현행',
#   '법령명한글': '간선급행버스체계의 건설 및 운영에 관한 특별법 시행령',
#   '법령약칭명': '간선급행버스법시행령',
#   '법령ID': '012179',
#   '공포일자': '20210420',
#   '공포번호': '31638',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210421',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=231641&type=HTML&mobileYn=&efYd=20210421'},
#  {'@id': '95',
#   '법령일련번호': '234955',
#   '현행연혁코드': '현행',
#   '법령명한글': '간선급행버스체계의 건설 및 운영에 관한 특별법 시행규칙',
#   '법령약칭명': '간선급행버스법시행규칙',
#   '법령ID': '012188',
#   '공포일자': '20210827',
#   '공포번호': '00882',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1613000',
#   '소관부처명': '국토교통부',
#   '법령구분명': '국토교통부령',
#   '시행일자': '20210827',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234955&type=HTML&mobileYn=&efYd=20210827'},
#  {'@id': '96',
#   '법령일련번호': '234135',
#   '현행연혁코드': '현행',
#   '법령명한글': '간척지의 농어업적 이용 및 관리에 관한 법률',
#   '법령약칭명': '간척지법',
#   '법령ID': '011522',
#   '공포일자': '20210720',
#   '공포번호': '18310',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '법률',
#   '시행일자': '20220721',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234135&type=HTML&mobileYn=&efYd=20220721'},
#  {'@id': '97',
#   '법령일련번호': '243641',
#   '현행연혁코드': '현행',
#   '법령명한글': '간척지의 농어업적 이용 및 관리에 관한 법률 시행령',
#   '법령약칭명': '간척지법시행령',
#   '법령ID': '011742',
#   '공포일자': '20220704',
#   '공포번호': '32754',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220705',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243641&type=HTML&mobileYn=&efYd=20220705'},
#  {'@id': '98',
#   '법령일련번호': '243729',
#   '현행연혁코드': '현행',
#   '법령명한글': '간척지의 농어업적 이용 및 관리에 관한 법률 시행규칙',
#   '법령약칭명': '간척지법시행규칙',
#   '법령ID': '011745',
#   '공포일자': '20220705',
#   '공포번호': '00538',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1543000',
#   '소관부처명': '농림축산식품부',
#   '법령구분명': '농림축산식품부령',
#   '시행일자': '20220705',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243729&type=HTML&mobileYn=&efYd=20220705'},
#  {'@id': '99',
#   '법령일련번호': '241727',
#   '현행연혁코드': '현행',
#   '법령명한글': '간호조무사 및 의료유사업자에 관한 규칙',
#   '법령약칭명': '간호조무사등규칙',
#   '법령ID': '006137',
#   '공포일자': '20220408',
#   '공포번호': '00879',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1352000',
#   '소관부처명': '보건복지부',
#   '법령구분명': '보건복지부령',
#   '시행일자': '20220408',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241727&type=HTML&mobileYn=&efYd=20220408'},
#  {'@id': '100',
#   '법령일련번호': '209959',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사교육원 운영 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '008770',
#   '공포일자': '20190715',
#   '공포번호': '00311',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20190715',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=209959&type=HTML&mobileYn=&efYd=20190715'},
#  {'@id': '101',
#   '법령일련번호': '191254',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사교육원직제',
#   '법령약칭명': None,
#   '법령ID': '008771',
#   '공포일자': '20170116',
#   '공포번호': '00296',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20170116',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=191254&type=HTML&mobileYn=&efYd=20170116'},
#  {'@id': '102',
#   '법령일련번호': '209960',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사연구원 운영규칙',
#   '법령약칭명': None,
#   '법령ID': '010116',
#   '공포일자': '20190715',
#   '공포번호': '00312',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20190715',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=209960&type=HTML&mobileYn=&efYd=20190715'},
#  {'@id': '103',
#   '법령일련번호': '211325',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사연구원 직제',
#   '법령약칭명': None,
#   '법령ID': '010032',
#   '공포일자': '20191108',
#   '공포번호': '00321',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20191108',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=211325&type=HTML&mobileYn=&efYd=20191108'},
#  {'@id': '104',
#   '법령일련번호': '243909',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 감사사무 처리규칙',
#   '법령약칭명': None,
#   '법령ID': '014263',
#   '공포일자': '20220714',
#   '공포번호': '00356',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20220714',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243909&type=HTML&mobileYn=&efYd=20220714'},
#  {'@id': '105',
#   '법령일련번호': '222733',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 개방형 직위 및 공모 직위의 운영 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '010476',
#   '공포일자': '20201102',
#   '공포번호': '00338',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20201102',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=222733&type=HTML&mobileYn=&efYd=20201102'},
#  {'@id': '106',
#   '법령일련번호': '184473',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원규칙의 공포에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '008773',
#   '공포일자': '20160630',
#   '공포번호': '00287',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20160630',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=184473&type=HTML&mobileYn=&efYd=20160630'},
#  {'@id': '107',
#   '법령일련번호': '243979',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 모범공직자 및 모범부서ㆍ기관 선발에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '014313',
#   '공포일자': '20220719',
#   '공포번호': '00357',
#   '제개정구분명': '제정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20220719',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243979&type=HTML&mobileYn=&efYd=20220719'},
#  {'@id': '108',
#   '법령일련번호': '222549',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원법',
#   '법령약칭명': None,
#   '법령ID': '001372',
#   '공포일자': '20201020',
#   '공포번호': '17560',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '법률',
#   '시행일자': '20201020',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=222549&type=HTML&mobileYn=&efYd=20201020'},
#  {'@id': '109',
#   '법령일련번호': '199620',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 변상판정청구에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '009168',
#   '공포일자': '20171208',
#   '공포번호': '00300',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20171208',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=199620&type=HTML&mobileYn=&efYd=20171208'},
#  {'@id': '110',
#   '법령일련번호': '220627',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원사무처 직제',
#   '법령약칭명': None,
#   '법령ID': '008775',
#   '공포일자': '20200803',
#   '공포번호': '00329',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20200803',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=220627&type=HTML&mobileYn=&efYd=20200803'},
#  {'@id': '111',
#   '법령일련번호': '173065',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 소관 비영리법인의 설립 및 감독에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '009830',
#   '공포일자': '20150717',
#   '공포번호': '00273',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20150717',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=173065&type=HTML&mobileYn=&efYd=20150717'},
#  {'@id': '112',
#   '법령일련번호': '241711',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원심사규칙',
#   '법령약칭명': None,
#   '법령ID': '008776',
#   '공포일자': '20220404',
#   '공포번호': '00347',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20220404',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241711&type=HTML&mobileYn=&efYd=20220404'},
#  {'@id': '113',
#   '법령일련번호': '241639',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 운영규칙',
#   '법령약칭명': None,
#   '법령ID': '008774',
#   '공포일자': '20220404',
#   '공포번호': '00348',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20220404',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241639&type=HTML&mobileYn=&efYd=20220404'},
#  {'@id': '114',
#   '법령일련번호': '209963',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 전문인력 및 전문직위의 운영 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '013525',
#   '공포일자': '20190715',
#   '공포번호': '00315',
#   '제개정구분명': '제정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20190715',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=209963&type=HTML&mobileYn=&efYd=20190715'},
#  {'@id': '115',
#   '법령일련번호': '184476',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 정책자문위원회 규칙',
#   '법령약칭명': None,
#   '법령ID': '009704',
#   '공포일자': '20160630',
#   '공포번호': '00290',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20160630',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=184476&type=HTML&mobileYn=&efYd=20160630'},
#  {'@id': '116',
#   '법령일련번호': '184477',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원 징계 규칙',
#   '법령약칭명': None,
#   '법령ID': '008779',
#   '공포일자': '20160630',
#   '공포번호': '00291',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20160630',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=184477&type=HTML&mobileYn=&efYd=20160630'},
#  {'@id': '117',
#   '법령일련번호': '147119',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사원행정심판위원회규칙',
#   '법령약칭명': None,
#   '법령ID': '011122',
#   '공포일자': '20131129',
#   '공포번호': '00247',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20131129',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=147119&type=HTML&mobileYn=&efYd=20131129'},
#  {'@id': '118',
#   '법령일련번호': '241709',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사위원회의 운영 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '012606',
#   '공포일자': '20220404',
#   '공포번호': '00347',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20220404',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241709&type=HTML&mobileYn=&efYd=20220404'},
#  {'@id': '119',
#   '법령일련번호': '106437',
#   '현행연혁코드': '현행',
#   '법령명한글': '감사활동조정협의회의 구성ㆍ운영 등에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '011226',
#   '공포일자': '20100706',
#   '공포번호': '00210',
#   '제개정구분명': '제정',
#   '소관부처코드': '1040000',
#   '소관부처명': '감사원',
#   '법령구분명': '감사원규칙',
#   '시행일자': '20100706',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=106437&type=HTML&mobileYn=&efYd=20100706'},
#  {'@id': '120',
#   '법령일련번호': '239281',
#   '현행연혁코드': '현행',
#   '법령명한글': '감염병의 예방 및 관리에 관한 법률',
#   '법령약칭명': '코로나19 감염병예방법',
#   '법령ID': '001792',
# ...
#   '공포일자': '20220603',
#   '공포번호': '00482',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1371000',
#   '소관부처명': '문화체육관광부',
#   '법령구분명': '문화체육관광부령',
#   '시행일자': '20220603',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242861&type=HTML&mobileYn=&efYd=20220603'},
#  {'@id': '961',
#   '법령일련번호': '242695',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민통합위원회의 설치 및 운영에 관한 규정',
#   '법령약칭명': None,
#   '법령ID': '014285',
#   '공포일자': '20220530',
#   '공포번호': '32653',
#   '제개정구분명': '제정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220530',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242695&type=HTML&mobileYn=&efYd=20220530'},
#  {'@id': '962',
#   '법령일련번호': '183569',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민투표법',
#   '법령약칭명': None,
#   '법령ID': '001723',
#   '공포일자': '20160529',
#   '공포번호': '14184',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '9760000',
#   '소관부처명': '중앙선거관리위원회',
#   '법령구분명': '법률',
#   '시행일자': '20161130',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=183569&type=HTML&mobileYn=&efYd=20161130'},
#  {'@id': '963',
#   '법령일련번호': '227305',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민투표법 시행령',
#   '법령약칭명': None,
#   '법령ID': '002847',
#   '공포일자': '20210105',
#   '공포번호': '31380',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1741000',
#   '소관부처명': '행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210105',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=227305&type=HTML&mobileYn=&efYd=20210105'},
#  {'@id': '964',
#   '법령일련번호': '61860',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민투표법시행규칙',
#   '법령약칭명': None,
#   '법령ID': '006037',
#   '공포일자': '19890325',
#   '공포번호': '00070',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '9760000',
#   '소관부처명': '중앙선거관리위원회',
#   '법령구분명': '중앙선거관리위원회규칙',
#   '시행일자': '19890325',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=61860&type=HTML&mobileYn=&efYd=19890325'},
#  {'@id': '965',
#   '법령일련번호': '239367',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민 평생 직업능력 개발법',
#   '법령약칭명': '평생직업능력법',
#   '법령ID': '000117',
#   '공포일자': '20220111',
#   '공포번호': '18751',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '법률',
#   '시행일자': '20220412',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=239367&type=HTML&mobileYn=&efYd=20220412'},
#  {'@id': '966',
#   '법령일련번호': '240457',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민 평생 직업능력 개발법 시행령',
#   '법령약칭명': None,
#   '법령ID': '003069',
#   '공포일자': '20220217',
#   '공포번호': '32447',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220218',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=240457&type=HTML&mobileYn=&efYd=20220218'},
#  {'@id': '967',
#   '법령일련번호': '240869',
#   '현행연혁코드': '현행',
#   '법령명한글': '국민 평생 직업능력 개발법 시행규칙',
#   '법령약칭명': None,
#   '법령ID': '006865',
#   '공포일자': '20220217',
#   '공포번호': '00347',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1492000',
#   '소관부처명': '고용노동부',
#   '법령구분명': '고용노동부령',
#   '시행일자': '20220218',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=240869&type=HTML&mobileYn=&efYd=20220218'},
#  {'@id': '968',
#   '법령일련번호': '224421',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방개혁에 관한 법률',
#   '법령약칭명': '국방개혁법',
#   '법령ID': '010359',
#   '공포일자': '20201222',
#   '공포번호': '17684',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20201222',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=224421&type=HTML&mobileYn=&efYd=20201222'},
#  {'@id': '969',
#   '법령일련번호': '243553',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방개혁에 관한 법률 시행령',
#   '법령약칭명': '국방개혁법시행령',
#   '법령ID': '010411',
#   '공포일자': '20220630',
#   '공포번호': '32743',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243553&type=HTML&mobileYn=&efYd=20220701'},
#  {'@id': '970',
#   '법령일련번호': '216183',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방과학기술혁신 촉진법',
#   '법령약칭명': '국방과학기술혁신법',
#   '법령ID': '013716',
#   '공포일자': '20200331',
#   '공포번호': '17163',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000 1690000',
#   '소관부처명': '국방부,방위사업청',
#   '법령구분명': '법률',
#   '시행일자': '20210401',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=216183&type=HTML&mobileYn=&efYd=20210401'},
#  {'@id': '971',
#   '법령일련번호': '230677',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방과학기술혁신 촉진법 시행령',
#   '법령약칭명': '국방과학기술혁신법시행령',
#   '법령ID': '014049',
#   '공포일자': '20210330',
#   '공포번호': '31557',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000 1690000',
#   '소관부처명': '국방부,방위사업청',
#   '법령구분명': '대통령령',
#   '시행일자': '20210401',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=230677&type=HTML&mobileYn=&efYd=20210401'},
#  {'@id': '972',
#   '법령일련번호': '230705',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방과학기술혁신 촉진법 시행규칙',
#   '법령약칭명': '국방과학기술혁신법시행규칙',
#   '법령ID': '014050',
#   '공포일자': '20210330',
#   '공포번호': '01049',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000 1690000',
#   '소관부처명': '국방부,방위사업청',
#   '법령구분명': '국방부령',
#   '시행일자': '20210401',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=230705&type=HTML&mobileYn=&efYd=20210401'},
#  {'@id': '973',
#   '법령일련번호': '169502',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방과학연구소법',
#   '법령약칭명': None,
#   '법령ID': '000943',
#   '공포일자': '20150327',
#   '공포번호': '13238',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20150327',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=169502&type=HTML&mobileYn=&efYd=20150327'},
#  {'@id': '974',
#   '법령일련번호': '237835',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방과학연구소법 시행령',
#   '법령약칭명': None,
#   '법령ID': '002850',
#   '공포일자': '20211216',
#   '공포번호': '32223',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220113',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=237835&type=HTML&mobileYn=&efYd=20220113'},
#  {'@id': '975',
#   '법령일련번호': '216227',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방ㆍ군사시설 사업에 관한 법률',
#   '법령약칭명': '국방시설사업법',
#   '법령ID': '000934',
#   '공포일자': '20200331',
#   '공포번호': '17171',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20210401',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=216227&type=HTML&mobileYn=&efYd=20210401'},
#  {'@id': '976',
#   '법령일련번호': '222935',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방ㆍ군사시설 사업에 관한 법률 시행령',
#   '법령약칭명': '국방시설사업법시행령',
#   '법령ID': '002853',
#   '공포일자': '20201124',
#   '공포번호': '31176',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20201124',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=222935&type=HTML&mobileYn=&efYd=20201124'},
#  {'@id': '977',
#   '법령일련번호': '182535',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방ㆍ군사시설 사업에 관한 법률 시행규칙',
#   '법령약칭명': '국방시설사업법시행규칙',
#   '법령ID': '006724',
#   '공포일자': '20160411',
#   '공포번호': '00891',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20160411',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=182535&type=HTML&mobileYn=&efYd=20160411'},
#  {'@id': '978',
#   '법령일련번호': '199083',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방ㆍ군사시설이전 특별회계법',
#   '법령약칭명': '국방시설이전회계법',
#   '법령ID': '010361',
#   '공포일자': '20171128',
#   '공포번호': '15046',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20180301',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=199083&type=HTML&mobileYn=&efYd=20180301'},
#  {'@id': '979',
#   '법령일련번호': '192435',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방대학교 설치법',
#   '법령약칭명': None,
#   '법령ID': '001974',
#   '공포일자': '20170321',
#   '공포번호': '14609',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20170622',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=192435&type=HTML&mobileYn=&efYd=20170622'},
#  {'@id': '980',
#   '법령일련번호': '234231',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방대학교 설치법 시행령',
#   '법령약칭명': None,
#   '법령ID': '002854',
#   '공포일자': '20210727',
#   '공포번호': '31908',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210727',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234231&type=HTML&mobileYn=&efYd=20210727'},
#  {'@id': '981',
#   '법령일련번호': '200755',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방대학교 학생 선발 및 수업료 징수에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '006726',
#   '공포일자': '20180102',
#   '공포번호': '00944',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20180102',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=200755&type=HTML&mobileYn=&efYd=20180102'},
#  {'@id': '982',
#   '법령일련번호': '207843',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부 군비통제검증단령',
#   '법령약칭명': None,
#   '법령ID': '002860',
#   '공포일자': '20190219',
#   '공포번호': '29554',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20190219',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=207843&type=HTML&mobileYn=&efYd=20190219'},
#  {'@id': '983',
#   '법령일련번호': '204074',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부군사편찬연구소령',
#   '법령약칭명': None,
#   '법령ID': '002856',
#   '공포일자': '20180717',
#   '공포번호': '29047',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20180717',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=204074&type=HTML&mobileYn=&efYd=20180717'},
#  {'@id': '984',
#   '법령일련번호': '241423',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부근무지원단령',
#   '법령약칭명': None,
#   '법령ID': '002861',
#   '공포일자': '20220311',
#   '공포번호': '32531',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220701',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=241423&type=HTML&mobileYn=&efYd=20220701'},
#  {'@id': '985',
#   '법령일련번호': '168783',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부 및 그 소속청 소관 비영리법인의 설립 및 감독에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '006733',
#   '공포일자': '20150225',
#   '공포번호': '00853',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20150225',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=168783&type=HTML&mobileYn=&efYd=20150225'},
#  {'@id': '986',
#   '법령일련번호': '242253',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부와 그 소속기관 직제',
#   '법령약칭명': None,
#   '법령ID': '002863',
#   '공포일자': '20220509',
#   '공포번호': '32629',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000 1741000',
#   '소관부처명': '국방부,행정안전부',
#   '법령구분명': '대통령령',
#   '시행일자': '20220509',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=242253&type=HTML&mobileYn=&efYd=20220509'},
#  {'@id': '987',
#   '법령일련번호': '243889',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부와 그 소속기관 직제 시행규칙',
#   '법령약칭명': None,
#   '법령ID': '006737',
#   '공포일자': '20220715',
#   '공포번호': '01090',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20220715',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=243889&type=HTML&mobileYn=&efYd=20220715'},
#  {'@id': '988',
#   '법령일련번호': '197996',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부장관의 소속청장 지휘에 관한 규칙',
#   '법령약칭명': None,
#   '법령ID': '010252',
#   '공포일자': '20171018',
#   '공포번호': '00938',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20171018',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=197996&type=HTML&mobileYn=&efYd=20171018'},
#  {'@id': '989',
#   '법령일련번호': '214029',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방부조사본부령',
#   '법령약칭명': None,
#   '법령ID': '002870',
#   '공포일자': '20200204',
#   '공포번호': '30384',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20200204',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=214029&type=HTML&mobileYn=&efYd=20200204'},
#  {'@id': '990',
#   '법령일련번호': '197248',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방시설본부령',
#   '법령약칭명': None,
#   '법령ID': '009596',
#   '공포일자': '20170905',
#   '공포번호': '28266',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20170905',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=197248&type=HTML&mobileYn=&efYd=20170905'},
#  {'@id': '991',
#   '법령일련번호': '155188',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방전직교육원법',
#   '법령약칭명': None,
#   '법령ID': '012072',
#   '공포일자': '20140611',
#   '공포번호': '12746',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20141212',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=155188&type=HTML&mobileYn=&efYd=20141212'},
#  {'@id': '992',
#   '법령일련번호': '165022',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방전직교육원법 시행령',
#   '법령약칭명': None,
#   '법령ID': '012184',
#   '공포일자': '20141209',
#   '공포번호': '25822',
#   '제개정구분명': '제정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20141212',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=165022&type=HTML&mobileYn=&efYd=20141212'},
#  {'@id': '993',
#   '법령일련번호': '205327',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방정보본부령',
#   '법령약칭명': None,
#   '법령ID': '002873',
#   '공포일자': '20181204',
#   '공포번호': '29322',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20181204',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=205327&type=HTML&mobileYn=&efYd=20181204'},
#  {'@id': '994',
#   '법령일련번호': '238769',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방정보화 기반조성 및 국방정보자원관리에 관한 법률',
#   '법령약칭명': '국방정보화법',
#   '법령ID': '011149',
#   '공포일자': '20220104',
#   '공포번호': '18682',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '법률',
#   '시행일자': '20220705',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=238769&type=HTML&mobileYn=&efYd=20220705'},
#  {'@id': '995',
#   '법령일련번호': '165794',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방정보화 기반조성 및 국방정보자원관리에 관한 법률 시행령',
#   '법령약칭명': '국방정보화법시행령',
#   '법령ID': '011322',
#   '공포일자': '20141230',
#   '공포번호': '25906',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20141230',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=165794&type=HTML&mobileYn=&efYd=20141230'},
#  {'@id': '996',
#   '법령일련번호': '175833',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방정보화 기반조성 및 국방정보자원관리에 관한 법률 시행규칙',
#   '법령약칭명': '국방정보화법시행규칙',
#   '법령ID': '011326',
#   '공포일자': '20151026',
#   '공포번호': '00873',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '국방부령',
#   '시행일자': '20151026',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=175833&type=HTML&mobileYn=&efYd=20151026'},
#  {'@id': '997',
#   '법령일련번호': '223181',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방정신전력원령',
#   '법령약칭명': None,
#   '법령ID': '012429',
#   '공포일자': '20201201',
#   '공포번호': '31200',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20201231',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=223181&type=HTML&mobileYn=&efYd=20201231'},
#  {'@id': '998',
#   '법령일련번호': '222641',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방조직 및 정원에 관한 통칙',
#   '법령약칭명': None,
#   '법령ID': '002876',
#   '공포일자': '20201027',
#   '공포번호': '31124',
#   '제개정구분명': '일부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20201027',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=222641&type=HTML&mobileYn=&efYd=20201027'},
#  {'@id': '999',
#   '법령일련번호': '234233',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방출판지원단령',
#   '법령약칭명': None,
#   '법령ID': '011042',
#   '공포일자': '20210727',
#   '공포번호': '31909',
#   '제개정구분명': '전부개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20210727',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=234233&type=HTML&mobileYn=&efYd=20210727'},
#  {'@id': '1000',
#   '법령일련번호': '199818',
#   '현행연혁코드': '현행',
#   '법령명한글': '국방통합데이터센터령',
#   '법령약칭명': None,
#   '법령ID': '012104',
#   '공포일자': '20171219',
#   '공포번호': '28475',
#   '제개정구분명': '타법개정',
#   '소관부처코드': '1290000',
#   '소관부처명': '국방부',
#   '법령구분명': '대통령령',
#   '시행일자': '20171221',
#   '자법타법여부': None,
#   '법령상세링크': '/DRF/lawService.do?OC=sapphire_5&target=law&MST=199818&type=HTML&mobileYn=&efYd=20171221'},
#  ...]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(xmlobject['LawSearch']['law'])
df.head()
# Out:
#   @id  법령일련번호 현행연혁코드                           법령명한글        법령약칭명    법령ID  \
# 0   1  232157     현행      10ㆍ27법난 피해자의 명예회복 등에 관한 법률     10ㆍ27법난법  010719
# 1   2  235703     현행  10ㆍ27법난 피해자의 명예회복 등에 관한 법률 시행령  10ㆍ27법난법시행령  010831
# 2   3  236231     현행                 119구조ㆍ구급에 관한 법률         119법  011349
# 3   4  236155     현행             119구조ㆍ구급에 관한 법률 시행령      119법시행령  011452
# 4   5  243963     현행            119구조ㆍ구급에 관한 법률 시행규칙     119법시행규칙  011457
#
#        공포일자   공포번호 제개정구분명   소관부처코드    소관부처명   법령구분명      시행일자 자법타법여부  \
# 0  20210518  18146   일부개정  1371000  문화체육관광부      법률  20210518   None
# 1  20210929  32018   타법개정  1371000  문화체육관광부    대통령령  20210929   None
# 2  20211019  18487   일부개정  1661000      소방청      법률  20220120   None
# 3  20211019  32070   일부개정  1661000      소방청    대통령령  20220106   None
# 4  20220721  00345   일부개정  1661000      소방청  행정안전부령  20220721   None
#
#                                               법령상세링크
# 0  /DRF/lawService.do?OC=sapphire_5&target=law&MS...
# 1  /DRF/lawService.do?OC=sapphire_5&target=law&MS...
# 2  /DRF/lawService.do?OC=sapphire_5&target=law&MS...
# 3  /DRF/lawService.do?OC=sapphire_5&target=law&MS...
# 4  /DRF/lawService.do?OC=sapphire_5&target=law&MS...

# %%
target = df['법령명한글'].values # 시리즈에 .values  하면 배열이 되자나
title_list = target.tolist() # 리스트로 변환
text = ' '.join(title_list)
text
# Out:
# '10ㆍ27법난 피해자의 명예회복 등에 관한 법률 10ㆍ27법난 피해자의 명예회복 등에 관한 법률 시행령 119구조ㆍ구급에 관한 법률 119구조ㆍ구급에 관한 법률 시행령 119구조ㆍ구급에 관한 법률 시행규칙 1945년이후종전의규정에의한학교졸업자자격인정령 1959년 12월 31일 이전에 퇴직한 군인의 퇴직급여금지급에 관한 특별법 1959년 12월 31일 이전에 퇴직한 군인의 퇴직급여금지급에 관한 특별법 시행령 1980년해직공무원의보상등에관한특별조치법 1980년해직공무원의보상등에관한특별조치법시행령 1인 창조기업 육성에 관한 법률 1인 창조기업 육성에 관한 법률 시행령 2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법 2018 평창 동계올림픽대회 및 동계패럴림픽대회 지원 등에 관한 특별법 시행령 2023 새만금 세계스카우트잼버리 지원 특별법 2023 새만금 세계스카우트잼버리 지원 특별법 시행령 2023 순천만국제정원박람회 지원 및 사후활용에 관한 특별법 2023 순천만국제정원박람회 지원 및 사후활용에 관한 특별법 시행령 2030 부산세계박람회 유치위원회의 설치 및 운영에 관한 규정 30개월 이상 복무한 상등병 만기전역자의 특별진급을 위한 특별법 30개월 이상 복무한 상등병 만기전역자의 특별진급을 위한 특별법 시행령 3ㆍ15의거 참여자의 명예회복 등에 관한 법률 3ㆍ15의거 참여자의 명예회복 등에 관한 법률 시행령 4ㆍ16세월호참사 진상규명 및 안전사회 건설 등을 위한 특별법 4ㆍ16세월호참사 진상규명 및 안전사회 건설 등을 위한 특별법 시행령 4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법 4ㆍ16세월호참사 피해구제 및 지원 등을 위한 특별법 시행령 4차산업혁명위원회의 설치 및 운영에 관한 규정 5ㆍ18민주유공자예우 및 단체설립에 관한 법률 5ㆍ18민주유공자예우 및 단체설립에 관한 법률 시행령 5ㆍ18민주유공자예우 및 단체설립에 관한 법률 시행규칙 5ㆍ18민주화운동 관련자 보상 등에 관한 법률 5ㆍ18민주화운동 관련자 보상 등에 관한 법률 시행령 5ㆍ18민주화운동 등에 관한 특별법 5ㆍ18민주화운동 진상규명을 위한 특별법 5ㆍ18민주화운동 진상규명을 위한 특별법 시행령 6ㆍ25 전사자유해의 발굴 등에 관한 법률 6ㆍ25 전사자유해의 발굴 등에 관한 법률 시행령 6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률 6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률 시행령 6ㆍ25전쟁 납북피해 진상규명 및 납북피해자 명예회복에 관한 법률에 의한 가족관계등록사무처리규칙 6ㆍ25전쟁 무공훈장 수여 등에 관한 법률 6ㆍ25전쟁 무공훈장 수여 등에 관한 법률 시행령 6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률 6ㆍ25전쟁 전후 적 지역에서 활동한 비정규군 공로자 보상에 관한 법률 시행령 6ㆍ25전쟁 정전60주년 기념 호국영웅기장 수여규칙 가덕도신공항 건설을 위한 특별법 가덕도신공항 건설을 위한 특별법 시행령 가덕도신공항 건설을 위한 특별법 시행규칙 가등기담보 등에 관한 법률 가맹사업거래의 공정화에 관한 법률 가맹사업거래의 공정화에 관한 법률 시행령 가맹사업 진흥에 관한 법률 가맹사업 진흥에 관한 법률 시행령 가사근로자의 고용개선 등에 관한 법률 가사근로자의 고용개선 등에 관한 법률 시행령 가사근로자의 고용개선 등에 관한 법률 시행규칙 가사소송규칙 가사소송법 가사소송수수료규칙 가석방자관리규정 가습기살균제 피해구제를 위한 특별법 가습기살균제 피해구제를 위한 특별법 시행령 가습기살균제 피해구제를 위한 특별법 시행규칙 가정보호심판규칙 가정폭력방지 및 피해자보호 등에 관한 법률 가정폭력방지 및 피해자보호 등에 관한 법률 시행령 가정폭력방지 및 피해자보호 등에 관한 법률 시행규칙 가정폭력범죄의 처벌 등에 관한 특례법 가정폭력범죄의 처벌 등에 관한 특례법 시행령 가족관계의 등록 등에 관한 규칙 가족관계의 등록 등에 관한 법률 가족친화 사회환경의 조성 촉진에 관한 법률 가족친화 사회환경의 조성 촉진에 관한 법률 시행령 가족친화 사회환경의 조성 촉진에 관한 법률 시행규칙 가축 및 축산물 이력관리에 관한 법률 가축 및 축산물 이력관리에 관한 법률 시행령 가축 및 축산물 이력관리에 관한 법률 시행규칙 가축분뇨의 관리 및 이용에 관한 법률 가축분뇨의 관리 및 이용에 관한 법률 시행령 가축분뇨의 관리 및 이용에 관한 법률 시행규칙 가축분뇨의 자원화 및 이용 촉진에 관한 규칙 가축전염병 예방법 가축전염병 예방법 시행령 가축전염병 예방법 시행규칙 각급 법원에 배치할 판사의 수에 관한 규칙 각급 법원의 설치와 관할구역에 관한 법률 각급 법원 판사 정원법 각급선거관리위원회회의규칙 각병과사병의군사경찰직무보조에관한규정 각종 기념일 등에 관한 규정 각종분쟁조정위원회등의조정조서등에대한집행문부여에관한규칙 간선급행버스체계의 건설 및 운영에 관한 특별법 간선급행버스체계의 건설 및 운영에 관한 특별법 시행령 간선급행버스체계의 건설 및 운영에 관한 특별법 시행규칙 간척지의 농어업적 이용 및 관리에 관한 법률 간척지의 농어업적 이용 및 관리에 관한 법률 시행령 간척지의 농어업적 이용 및 관리에 관한 법률 시행규칙 간호조무사 및 의료유사업자에 관한 규칙 감사교육원 운영 등에 관한 규칙 감사교육원직제 감사연구원 운영규칙 감사연구원 직제 감사원 감사사무 처리규칙 감사원 개방형 직위 및 공모 직위의 운영 등에 관한 규칙 감사원규칙의 공포에 관한 규칙 감사원 모범공직자 및 모범부서ㆍ기관 선발에 관한 규칙 감사원법 감사원 변상판정청구에 관한 규칙 감사원사무처 직제 감사원 소관 비영리법인의 설립 및 감독에 관한 규칙 감사원심사규칙 감사원 운영규칙 감사원 전문인력 및 전문직위의 운영 등에 관한 규칙 감사원 정책자문위원회 규칙 감사원 징계 규칙 감사원행정심판위원회규칙 감사위원회의 운영 등에 관한 규칙 감사활동조정협의회의 구성ㆍ운영 등에 관한 규칙 감염병의 예방 및 관리에 관한 법률 감염병의 예방 및 관리에 관한 법률 시행령 감염병의 예방 및 관리에 관한 법률 시행규칙 감정평가 및 감정평가사에 관한 법률 감정평가 및 감정평가사에 관한 법률 시행령 감정평가 및 감정평가사에 관한 법률 시행규칙 감정평가에 관한 규칙 개발이익 환수에 관한 법률 개발이익 환수에 관한 법률 시행령 개발이익 환수에 관한 법률 시행규칙 개발제한구역의 지정 및 관리에 관한 특별조치법 개발제한구역의 지정 및 관리에 관한 특별조치법 시행령 개발제한구역의 지정 및 관리에 관한 특별조치법 시행규칙 개방형 직위 및 공모 직위의 운영 등에 관한 규정 개별소비세법 개별소비세법 시행령 개별소비세법 시행규칙 개성공업지구 지원에 관한 법률 개성공업지구 지원에 관한 법률 시행령 개성공업지구 지원에 관한 법률 시행규칙 개인정보 단체소송규칙 개인정보 보호법 개인정보 보호법 시행령 개인정보 보호위원회 직제 개인정보 보호위원회 직제 시행규칙 갯벌 및 그 주변지역의 지속가능한 관리와 복원에 관한 법률 갯벌 및 그 주변지역의 지속가능한 관리와 복원에 관한 법률 시행령 갯벌 및 그 주변지역의 지속가능한 관리와 복원에 관한 법률 시행규칙 거절증서령 거창사건등 관련자의 명예회복에 관한 특별조치법 거창사건등 관련자의 명예회복에 관한 특별조치법 시행령 건강가정기본법 건강가정기본법 시행령 건강가정기본법 시행규칙 건강검진기본법 건강검진기본법 시행령 건강검진기본법 시행규칙 건강기능식품에 관한 법률 건강기능식품에 관한 법률 시행령 건강기능식품에 관한 법률 시행규칙 건널목 개량촉진법 건널목 개량촉진법 시행령 건널목 입체교차화 비용부담에 관한 규칙 건설근로자의 고용개선 등에 관한 법률 건설근로자의 고용개선 등에 관한 법률 시행령 건설근로자의 고용개선 등에 관한 법률 시행규칙 건설근로자의 기능등급확인증 발급 등에 관한 규칙 건설기계관리법 건설기계관리법 시행령 건설기계관리법 시행규칙 건설기계 안전기준에 관한 규칙 건설기술 진흥법 건설기술 진흥법 시행령 건설기술 진흥법 시행규칙 건설산업기본법 건설산업기본법 시행령 건설산업기본법 시행규칙 건설폐기물의 재활용촉진에 관한 법률 건설폐기물의 재활용촉진에 관한 법률 시행령 건설폐기물의 재활용촉진에 관한 법률 시행규칙 건전가정의례의 정착 및 지원에 관한 법률 건전가정의례 ...

# %%
import re
text = re.sub('[^가-힣]+', ' ', text)
print(len(text))
text[:100]
# Out:
# 96156
# ' 법난 피해자의 명예회복 등에 관한 법률 법난 피해자의 명예회복 등에 관한 법률 시행령 구조 구급에 관한 법률 구조 구급에 관한 법률 시행령 구조 구급에 관한 법률 시행규칙 년이후'

# %%
# 형태소 분석을 해주는 konlpy

from konlpy.tag import Okt

okt = Okt()
morph = okt.pos(text)  # pos 단어와 품사를 뽑아줌
noun_list = []
for word, tag in morph:
    if (tag=='Noun') & (len(word) > 1): # Noun이고 단어 1글자 이상인것 뽑아줌 의미있눈거! 한글자는 조사자나
        noun_list.append(word)
#print(morph)
print(noun_list)
# Out:
# ['법난', '피해자', '명예', '회복', '법률', '법난', '피해자', '명예', '회복', '법률', '시행', '구조', '구급', '법률', '구조', '구급', '법률', '시행', '구조', '구급', '법률', '시행', '규칙', '이후', '종전', '규정', '학교', '졸업', '자격', '정령', '이전', '퇴직', '군인', '퇴직', '금지', '특별법', '이전', '퇴직', '군인', '퇴직', '금지', '특별법', '시행', '해직', '공무원', '보상', '특별', '조치', '해직', '공무원', '보상', '특별', '조치', '시행', '창조', '기업', '육성', '법률', '창조', '기업', '육성', '법률', '시행', '평창', '동계올림픽', '대회', '동계', '패럴림픽', '대회', '지원', '특별법', '평창', '동계올림픽', '대회', '동계', '패럴림픽', '대회', '지원', '특별법', '시행', '새만금', '세계', '스카우트', '잼버리', '지원', '특별법', '새만금', '세계', '스카우트', '잼버리', '지원', '특별법', '시행', '순천만', '국제', '정원', '박람회', '지원', '사후', '활용', '특별법', '순천만', '국제', '정원', '박람회', '지원', '사후', '활용', '특별법', '시행', '부산', '세계박람회', '유치', '위원회', '설치', '운영', '규정', '개월', '이상', '복무', '상등병', '전역', '특별', '진급', '특별법', '개월', '이상', '복무', '상등병', '전역', '특별', '진급', '특별법', '시행', '의거', '참여자', '명예', '회복', '법률', '의거', '참여자', '명예', '회복', '법률', '시행', '세월호', '참사', '진상', '규명', '안전', '사회', '건설', '특별법', '세월호', '참사', '진상', '규명', '안전', '사회', '건설', '특별법', '시행', '세월호', '참사', '피해', '구제', '지원', '특별법', '세월호', '참사', '피해', '구제', '지원', '특별법', '시행', '산업혁명', '위원회', '설치', '운영', '규정', '민주', '유공', '단체', '설립', '법률', '민주', '유공', '단체', '설립', '법률', '시행', '민주', '유공', '단체', '설립', '법률', '시행', '규칙', '민주화', '운동', '관련', '보상', '법률', '민주화', '운동', '관련', '보상', '법률', '시행', '민주화', '운동', '특별법', '민주화', '운동', '진상', '규명', '특별법', '민주화', '운동', '진상', '규명', '특별법', '시행', '사자', '유해', '발굴', '법률', '사자', '유해', '발굴', '법률', '시행', '전쟁', '납북', '피해', '진상', '규명', '납북', '피해자', '명예', '회복', '법률', '전쟁', '납북', '피해', '진상', '규명', '납북', '피해자', '명예', '회복', '법률', '시행', '전쟁', '납북', '피해', '진상', '규명', '납북', '피해자', '명예', '회복', '법률', '가족', '관계', '등록', '사무', '처리', '규칙', '전쟁', '무공훈장', '수여', '법률', '전쟁', '무공훈장', '수여', '법률', '시행', '전쟁', '전후', '지역', '활동', '정규', '공로', '보상', '법률', '전쟁', '전후', '지역', '활동', '정규', '공로', '보상', '법률', '시행', '전쟁', '정전', '주년', '기념', '호국', '영웅기', '수여', '규칙', '가덕도', '공항', '건설', '특별법', '가덕도', '공항', '건설', '특별법', '시행', '가덕도', '공항', '건설', '특별법', '시행', '규칙', '가등기담보', '법률', '가맹', '사업', '거래', '정화', '법률', '가맹', '사업', '거래', '정화', '법률', '시행', '가맹', '사업', '진흥', '법률', '가맹', '사업', '진흥', '법률', '시행', '가사', '근로자', '고용', '개선', '법률', '가사', '근로자', '고용', '개선', '법률', '시행', '가사', '근로자', '고용', '개선', '법률', '시행', '규칙', '가사소송', '규칙', '가사소송법', '가사소송', '수수료', '규칙', '가석방', '관리', '규정', '가습기', '살균제', '피해', '구제', '특별법', '가습기', '살균제', '피해', '구제', '특별법', '시행', '가습기', '살균제', '피해', '구제', '특별법', '시행', '규칙', '가정', '보호', '심판', '규칙', '가정폭력', '방지', '피해자', '보호', '법률', '가정폭력', '방지', '피해자', '보호', '법률', '시행', '가정폭력', '방지', '피해자', '보호', '법률', '시행', '규칙', '가정폭력', '범죄', '처벌', '특례법', '가정폭력', '범죄', '처벌', '특례법', '시행', '가족', '관계', '등록', '규칙', '가족', '관계', '등록', '법률', '가족', '사회', '환경', '조성', '촉진', '법률', '가족', '사회', '환경', '조성', '촉진', '법률', '시행', '가족', '사회', '환경', '조성', '촉진', '법률', '시행', '규칙', '가축', '축산물', '이력', '관리', '법률', '가축', '축산물', '이력', '관리', '법률', '시행', '가축', '축산물', '이력', '관리', '법률', '시행', '규칙', '가축', '분뇨', '관리', '이용', '법률', '가축', '분뇨', '관리', '이용', '법률', '시행', '가축', '분뇨', '관리', '이용', '법률', '시행', '규칙', '가축', '분뇨', '자원', '이용', '촉진', '규칙', '가축', '전염병', '방법', '가축', '전염병', '방법', '시행', '가축', '전염병', '방법', '시행', '규칙', '법원', '배치', '판사', '규칙', '법원', '설치', '관할', '구역', '법률', '법원', '판사', '정원', '선거', '관리', '위원회', '회의', '규칙', '병과', '사병', '군사', '경찰', '직무', '보조', '규정', '각종', '기념일', '규정', '각종', '분쟁', '조정', '위원회', '조정', '대한', '집행', '부여', '규칙', '간선', '급행버스', '체계', '건설', '운영', '특별법', '간선', '급행버스', '체계', '건설', '운영', '특별법', '시행', '간선', '급행버스', '체계', '건설', '운영', '특별법', '시행', '규칙', '간척지', '농어', '업적', '이용', '관리', '법률', '간척지', '농어', '업적', '이용', '관리', '법률', '시행', '간척지', '농어', '업적', '이용', '관리', '법률', '시행', '규칙', '간호조무사', '의료', '유사', '업자', '규칙', '감사', '교육', '운영', '규칙', '감사', '교육', '직제', '감사', '연구원', '운영', '규칙', '감사', '연구원', '직제', '감사원', '감사', '사무', '처리', '규칙', '감사원', '개방', '직위', '공모', '직위', '운영', '규칙', '감사원', '규칙', '공포', '규칙', '감사원', '모범', '공직자', '모범', '부서', '기관', '선발', '규칙', '감사원', '감사원', '변상', '판정', '청구', '규칙', '감사원', '사무', '직제', '감사원', '소관', '비영리', '법인', '설립', '감독', '규칙', '감사원', '심사', '규칙', '감사원', '운영', ...

# %%
from collections import Counter
one_word = []
for word, tag in morph:
    if (tag=='Noun') & (len(word)==1):
        one_word.append(word)
one_dict = dict(Counter(one_word).most_common())
keys = sorted(one_dict.items(), key=lambda x:x[1], reverse=True)
keys[:10]
# Out:
# [('관', 2398),
#  ('령', 1496),
#  ('법', 1450),
#  ('및', 1257),
#  ('등', 743),
#  ('위', 146),
#  ('그', 100),
#  ('군', 37),
#  ('제', 37),
#  ('업', 36)]

# %% [markdown]
# #### 가장 많이 쓰인 단어 카운트

# %%
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

rc('font',family='Malgun Gothic') # 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series, columns=['cnt'])
df10 = df.sort_values(by='cnt',ascending=False)[:10]
df10.reset_index(inplace=True)
df10
# Out:
#   index   cnt
# 0    시행  2445
# 1    규칙  1754
# 2    법률  1481
# 3    관리   535
# 4    지원   364
# 5    규정   327
# 6   특별법   318
# 7    진흥   284
# 8    산업   276
# 9    운영   247

# %%
sns.barplot(x='index', y='cnt', data=df10, orient='v')
# Out:
# <AxesSubplot:xlabel='index', ylabel='cnt'>

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\lynn5\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=2000,height=1500).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1999.5, 1499.5, -0.5)

# %% [markdown]
# #### 과제 0722_1
#
# 관심있는 카테고리 text 데이터를 웹에서 가져와서 시각화 하세요.(bar, wordcloud 등등)

# %%
url = 'https://search.naver.com/search.naver?sm=tab_sug.top&where=nexearch&query=%EC%A0%9C%EC%A3%BC%EB%8F%84&oquery=%EC%A0%9C%EC%A3%BC%EB%8F%84+%EB%82%A0%EC%94%A8&tqi=hW3%2Ffwp0J1ZsshQZZIKssssstJN-523167&acq=%EC%A0%9C%EC%A3%BC%EB%8F%84&acr=1&qdt=0'

import requests
from bs4 import BeautifulSoup as bs
import xmltodict

# %%
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
data = bs(req.text)
data
# Out:
# <!DOCTYPE html>
# <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="제주도 : 네이버 통합검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>제주도 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220714.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_220714.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; ex ...
# <link as="style" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/4-24e0959d.css" rel="preload"/>
# <link as="style" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/14-4805fcf3.css" rel="preload"/>
# <link as="style" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/main-cc2d5eb9.css" rel="preload"/>
# <link as="script" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/runtime~main-bundle-145de005.js" rel="preload"/>
# <link as="script" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/main-bundle-cc2d5eb9.js" rel="preload"/>
# <link as="script" data-chunk="components-mainContainer" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/components-mainContainer-bundle-1e013ce3.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/13-bundle-5b52c651.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/12-bundle-339f9425.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/14-bundle-4805fcf3.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/pages-info-bundle-24e0959d.js" rel="preload"/>
# <link data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/main-cc2d5eb9.css" rel="stylesheet"/>
# <link data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/14-4805fcf3.css" rel="stylesheet"/>
# <link data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/4-24e0959d.css" rel="stylesheet"/>
# <div id="nxTsDo"><div class="nx_ts_do as_pc sc_new no-webkit"><style>
#     .nx_ts_do .Header {
#       border-top-color: rgba(165, 155, 117, 0.35);
#       background-color: rgb(237, 237, 230);
#     }
#     .nx_ts_do .Header .title > .details {
#     }
#     .nx_ts_do .Header .gnb_list::after {
#       background-image: linear-gradient(to left, rgb(237, 237, 230), rgba(237, 237, 230, 0));
#     }
#     .nx_ts_do .Header .gnb_list .list {
#       color: rgb(140, 130, 91);
#     }
#     .nx_ts_do .Header .gnb_list .list .item[aria-selected="true"] .anchor {
#       background-color: rgb(165, 155, 117);
#     }
#     .nx_ts_do .Header .gnb_list .list .item .anchor::before {
#       background-color: rgba(165, 155, 117, 0.3);
#     }
#     .nx_ts_do .Header .sub_title {
#       color: rgba(140, 130, 91, 0.8);
#     }
#     .nx_ts_do.as_mo .Header.is_fixed .inner {
#       background-color: rgb(237, 237, 230);
#       border-bottom-color: rgba(165, 155, 117, 0.28);
#       box-shadow: 0 0 4px 0 rgba(237, 237, 230, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#     }
#     .nx_ts_do.as_mo .Header.is_fixed_footer .inner {
#       background-color: rgb(237, 237, 230);
#     }
#     .nx_ts_do .do_content {
#       background-image: linear-gradient(to bottom, rgb(237, 237, 230) 128px, rgb(244, 244, 241) 377px);
#     }
#     .nx_ts_do.as_mo .do_content {
#       border-bottom-color: rgba(165, 155, 117, 0.35);
#     }
#     .nx_ts_do .Summary .indent_information,
#     .nx_ts_do .Info .indent_information {
#       border-left-color: rgba(237, 237, 230, 0.9);
#     }
#     .nx_ts_do .Summary .filters .multiple,
#     .nx_ts_do .Summary .filters .button[aria-selected="true"],
#     .nx_ts_do .Reservation .reservation_rooms .button[aria-selected="true"],
#     .nx_ts_do .Guide .filter .Tag[aria-selected='true'],
#     .nx_ts_do .Package_filters .filter[aria-selected='true'],
#     .nx_ts_do [data-theme-selector="FilterItem"][aria-selected='true'] {
#       border-color: rgba(165, 155, 117, 0.5);
#       color: rgb(140, 130, 91);
#       background-color: rgba(165, 155, 117, 0.03);
#     }
#     .nx_ts_do.as_pc .NavTagItem[aria-selected='true'],
#     .nx_ts_do.as_mo .NavTagItem[aria-selected='true'] {
#       color: rgb(140, 130, 91);
#       border-color: rgb(165, 155, 117);
#     }
#     .nx_ts_do .Reservation .ReservationNavTabs .tab[aria-selected="true"] {
#       border-color: rgba(165, 155, 117, 0.5);
#       color: rgb(140, 130, 91);
#     }
#     .nx_ts_do .Summary .filters .multiple::after {
#       border-top-color: rgb(165, 155, 117);
#     }
#     .nx_ts_do .tab_list {
#       color: rgb(140, 130, 91);
#       border-color: rgb(165, 155, 117);
#     }
#     .nx_ts_do.as_pc .Summary .spots .figcaption > .rank {
#       background-color: rgb(140, 130, 91);
#     }
#     .nx_ts_do.as_mo .Summary .spots .figcaption > .rank {
#       background-color: rgba(140, 130, 91, 0.8);
#     }
#     .nx_ts_do .Info .alert {
#       color: rgb(140, 130, 91);
#       background-color: rgba(165, 155, 117, 0.06);
#     }
#     .nx_travelsearch .border {
#       border-bottom-color: rgba(165, 155, 117, 0.28);
#     }
#     .nx_travelsearch .top_box {
#       box-shadow: 0 0 4px 0 rgba(165, 155, 117, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#     }
#     .nx_travelsearch .api_save_group .btn_save .ico_save,
#     .nx_travelsearch .api_save_group .btn_save.dimmed .ico_save {
#       background-color: rgb(165, 155, 117);
#     }
#     .nx_travelsearch .title_area .sub_title .cm_bar {
#       background-color: rgba(165, 155, 117, 0.3);
#     }
#     .nx_travelsearch .detail_info .cm_bar {
#       background-color: rgba(237, 237, 230);
#     }
#     .nx_travelsearch .TopPoi .thumb > .rank {
#       background-color: rgba(140, 130, 91, 0.8);
#     }
#     .nx_travelsearch .TopCity .thumb > .rank {
#       background-color: rgba(140, 130, 91, 0.8);
#     }
#     .nx_ts_do [data-theme-selector='NaviCities-cities'] {
#       border-color: rgba(165, 155, 117, 0.3);
#     }
#     .nx_ts_do [data-theme-selector='NaviCities-city'][aria-selected='true'] {
#       background-color: rgba(140, 130, 91, 0.05);
#     }
#
#     @media (prefers-color-scheme: dark) {
#       .nx_ts_do.is_color_scheme_acceptable .Header {
#         border-top-color: rgba(165, 155, 117, 0.35);
#         background-color: rgb(237, 237, 230);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .title > .details .summary,
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Header .info {
#         border-color: rgb(140, 130, 91);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .title > .details .summary::before,
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Header .info::before {
#         border-color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .title > .details {
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list::after {
#         background-image: linear-gradient(to left, rgb(237, 237, 230), rgba(237, 237, 230, 0));
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list {
#         color: rgb(140, 130, 91);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list .item[aria-selected="true"] .anchor {
#         background-color: rgb(165, 155, 117);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list .item .anchor::before {
#         background-color: rgba(165, 155, 117, 0.3);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .sub_title {
#         color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed .inner {
#         background-color: rgb(237, 237, 230);
#         border-bottom-color: rgba(165, 155, 117, 0.28);
#         box-shadow: 0 0 4px 0 rgba(237, 237, 230, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed_footer .inner {
#         background-color: rgb(237, 237, 230);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .do_content {
#         background-image: linear-gradient(to bottom, rgb(237, 237, 230) 128px, rgb(244, 244, 241) 377px);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .do_content {
#         border-bottom-color: rgba(165, 155, 117, 0.35);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .indent_information,
#       .nx_ts_do.is_color_scheme_acceptable .Info .indent_information {
#         border-left-color: rgba(237, 237, 230, 0.9);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .multiple,
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .button[aria-selected="true"],
#       .nx_ts_do.is_color_scheme_acceptable .Reservation .reservation_rooms .button[aria-selected="true"],
#       .nx_ts_do.is_color_scheme_acceptable .Guide .filter .Tag[aria-selected='true'],
#       .nx_ts_do.is_color_scheme_acceptable .Package_filters .filter[aria-selected='true'],
#       .nx_ts_do.is_color_scheme_acceptable [data-theme-selector="FilterItem"][aria-selected='true'] {
#         border-color: rgb(165, 155, 117);
#         color: #f0f0f2;
#         background-color: rgb(165, 155, 117);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Reservation .ReservationNavTabs .tab[aria-selected="true"] {
#         border-color: #f0f0f2;
#         color: #f0f0f2;
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .multiple::after {
#         border-top-color: rgb(165, 155, 117);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .tab_list {
#         color: rgb(140, 130, 91);
#         border-color: rgb(165, 155, 117);
#       }
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Summary .spots .figcaption > .rank {
#         background-color: rgb(140, 130, 91);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Summary .spots .figcaption > .rank {
#         background-color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Info .alert {
#         color: rgb(140, 130, 91);
#         background-color: rgba(165, 155, 117, 0.06);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .border {
#         border-bottom-color: rgba(165, 155, 117, 0.28);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .top_box {
#         box-shadow: 0 0 4px 0 rgba(165, 155, 117, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .api_save_group .btn_save .ico_save,
#       .nx_travelsearch.is_color_scheme_acceptable .api_save_group .btn_save.dimmed .ico_save {
#         background-color: rgb(165, 155, 117);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .title_area .sub_title .cm_bar{
#         background-color: rgba(165, 155, 117, 0.3);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .detail_info .cm_bar {
#         background-color: rgba(237, 237, 230);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .TopPoi .thumb > .rank {
#         background-color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .TopCity .thumb > .rank {
#         background-color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header {
#         border-top-color: rgba(165, 155, 117, 0.35);
#         background-color: #303033;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed .inner {
#         background-color: #303033;
#         box-shadow: none;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .cities {
#         border-color: rgba(165, 155, 117, 0.3);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .city[aria-selected="true"] {
#         background-color: rgba(140, 130, 91, 0.2);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .do_content {
#         border-bottom-color: rgba(140, 130, 91, 0.3);
#         background-image: none;
#         background-color: #303033;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .sub_title {
#         color: rgba(140, 130, 91, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .gnb_list::after {
#         background-image: linear-gradient(270deg, #303033, rgba(48, 49, 51, 0));
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Summary .indent_information,
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Info .indent_information {
#         border-left-color: rgba(140, 130, 91, 0.2);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable [data-theme-selector='NaviCities-cities'] {
#         border-color: rgba(165, 155, 117, 0.3);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable [data-theme-selector='NaviCities-city'][aria-selected='true'] {
#         background-color: rgba(140, 130, 91, 0.05);
#       }
#     }
#   </style><div class="Header"><div class="inner"><div class="titles"><div class="title"><h2 class="text"><a aria-current="false" aria-selected="false" class="anchor" href="https://travel.naver.com/domestic/14/summary" rel="noreferrer noopener" target="_blank">제주특별자치도</a></h2><div class="info"><button class="button as_7" style="color:rgb(140,130,91)" type="button">다른지역보기</button></div></div><div class="sub_title"><span class="text">Jeju</span></div></div><div class="gnb_list"><div class="inner"><ul class="list" role="tablist"><li aria-selected="false" class="item" role="tab"><a aria-current="false" aria-selected="false" class="anchor" href="#"><span class="text">전체</span></a></li><li aria-selected="false" class="item" role="tab"><a aria-current="false" aria-selected="false" class="anchor" href="#"><span class="text">여행콘텐츠</span></a></li><li aria-selected="false" class="item" role="tab"><a aria-current="false" aria-selected="false" class="anchor" href="#"><span class="text">상품예약</span></a></li><li aria-selected="true" class="item" role="tab"><a aria-current="false" aria-selected="false" class="anchor" href="#"><span class="text">도시정보</span></a></li></ul></div></div></div></div><div class="do_content"><div class="Info"><div class="Card-q-CCU"><div class="header-lQEOc"><h3 class="subject-yEf4l">도시정보</h3></div><div class="CityInfo-a0tzq"><p class="desc-rMoak">한국·중국·일본 등 극동 지역의 중앙부에 있어 지정학적으로도 중요하며, 도 전체가 바다로 둘러싸였다. 수리적(數理的)으로는 동경 126°08'∼126°58', 북위 33°06'∼34°00'에 위치한다. 북단은 북위 34°00'의 제주시 추자면 대서리이며, 남단은 북위 33°06'의 서귀포시 대정읍 마라도다. 한국 최남단에 있는 도로서, 제주도를 포함해 9개의 유인도와 55개의 무인도로 이루어졌다. 이 가운데 유인도는 우도·상추자도·하추자도·비양도·횡간도·추포도·가파도·마라도이다. 남북 간의 거리가 약 31㎞, 동서간의 거리가 약 73㎞로 동서로 가로놓인 모양이다. 러시아·중국 등의 대륙과 일본·동남아 등지를 연결하는 요충지이며, 천혜의 자연경관이 수려한 세계적인 휴양관광지다.</p><div class="info-lkQtK"><div class="CityInfo_InfoItem-lpF3v"><span class="criteria-hWW7e">관련</span><span class="value-SPlYe"><a aria-current="false" aria-selected="false" class="anchor-ltCTE" href="https://www.visitjeju.net/kr" rel="noreferrer noopener" target="_blank">비짓제주</a><a aria-current="false" aria-selected="false" class="anchor-ltCTE" href="https://map.naver.com/v5/search/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84" rel="noreferrer noopener" target="_blank">지도</a></span></div><div class="CityInfo_InfoItem-lpF3v"><span class="criteria-hWW7e">행정구역</span><span class="value-SPlYe"><a aria-current="false" aria-selected="false" class="area-E2h3U" href="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84+%EC%A0%9C%EC%A3%BC%EC%8B%9C&amp;mra=RFJUX1RSQQ%3D%3D&amp;x_bifrost=%7B%22nqx%22%3A%7B%22rcode%22%3A%2214110%22%2C%22ptnCode%22%3A%22info%22%7D%7D&amp;sm=tab_clk.dtr" target="_self">제주시</a><a aria-current="false" aria-selected="false" class="area-E2h3U" href="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84+%EC%84%9C%EA%B7%80%ED%8F%AC%EC%8B%9C&amp;mra=RFJUX1RSQQ%3D%3D&amp;x_bifrost=%7B%22nqx%22%3A%7B%22rcode%22%3A%2214130%22%2C%22ptnCode%22%3A%22info%22%7D%7D&amp;sm=tab_clk.dtr" target="_self">서귀포시</a></span></div></div></div></div><div class="Card-q-CCU"><div class="header-lQEOc"><h3 class="subject-yEf4l">날씨정보</h3></div><div class="WeatherInfo-pzCbT"><div class="TodayWeather-yPRTz"><span aria-label="구름많음" class="weather-bcy51 as_5-u3ZdN"></span><div class="info-VD2W0"><b class="now-ODt8o"><span class="value-knefW">27.5</span><sup class="sup-SkXyU">℃</sup></b><p class="summary-L8+5o">구름많음. 어제보다 0.4˚ 낮아요</p><div class="temperatures-15rB+"><div class="extreme-+5mqa"><span class="lowest-I3SJH">24<!-- -->°</span><span class="highest-P0yi9">29<!-- -->°</span></div><div class="experience-2EbOh"><span class="text-GJHJS">체감온도</span><span class="value-knefW">29.5<!-- -->℃</span></div></div></div><div class="side-asbSi"><div class="item-cy4YI"><span class="subject-dpOB9">미세먼지</span><span class="value-knefW as_good-SC+ie">17㎍/㎥ 좋음</span></ ...
# <script>
#   typeof window.naver === 'undefined' && (window.naver = {});
#   naver.search = naver.search || {};
#   naver.search.ext = naver.search.ext || {};
#   naver.search.ext.travelSearch = naver.search.ext.travelSearch || {};
#   naver.search.ext.travelSearch.__REACT_QUERY_STATE__ = {"mutations":[],"queries":[{"state":{"data":{"domesticCommonInfo":{"nameKo":"제주","nameEn":"Jeju","exposeTitle":"제주특별자치도","userActionLog":"https://travel-log.naver.com/logs/dtr-geo-click?q=-bsECfthf8b_MLriykczyf9eJLv65ScmrsnQScTSR4O8kBsx0soSG2dwieAwAGI-_UtnqLBv-Gv8TriT0XAejodttTJ0iYSaqnkiWzdDLU9BTiSg1x2HtlsbJ8UUK5PsHt9Wxv_s1NgNSejIZe_934whWku8wGLQgyMDQ1YjIYxyqTJUOXWDAlIxEVQ07h9tND_q1FY14dEhIEc4nSA0KUWtdtjUpBBnugf0hbLIqzSIhY4Nk1uiriVlUPVBEa4jpCCm-z7Lx8cMdwLr6zddNnDj23R6Y_hT1Ba--jOkStsJs5lf-FuYPXJGkJoJ3bUjHD8pRUshfcWUnByeGbICNFUh2lKyAMGHSWklLPcS253wbYZCHta9M67zKjDQqq-O6TaU4Ps8nR9L_RjwNp6qW8YQCVCUn389ZbMLVynkDuk=&nolog=0","themeColor":[[165,155,117],[140,130,91],[237,237,230],[244,244,241]],"darkModeThemeColor":[[165,155,117],[140,130,91],[237,237,230],[244,244,241]],"tabList":["summary","guide","sights","reservation","info"],"defaultProduct":"숙소","defaultAccommoProduct":"호텔","naviCities":[{"rcode":"14","nameKo":"제주","exposeTitle":"제주특별자치도"},{"rcode":"01","nameKo":"강원도","exposeTitle":"강원도"},{"rcode":"08","nameKo":"부산","exposeTitle":"부산광역시"},{"rcode":"09","nameKo":"서울","exposeTitle":"서울특별시"},{"rcode":"02","nameKo":"경기도","exposeTitle":"경기도"},{"rcode":"11","nameKo":"인천","exposeTitle":"인천광역시"},{"rcode":"16","nameKo":"충북","exposeTitle":"충청북도"},{"rcode":"15","nameKo":"충남","exposeTitle":"충청남도"},{"rcode":"04","nameKo":"경북","exposeTitle":"경상북도"},{"rcode":"03","nameKo":"경남","exposeTitle":"경상남도"},{"rcode":"13","nameKo":"전북","exposeTitle":"전라북도"},{"rcode":"12","nameKo":"전남","exposeTitle":"전라남도"}]},"domesticGeoInfo":{"hotel":{"hotels":[{"name":"롯데 호텔 제주"}]},"resort":{"hotels":[{"name":"더큐브 리조트 제주"}]},"pension":{"products":[{"title":"제이앤클로이"}]},"camping":{"products":[{"title":"다인리조트"}]},"airportInfo":{"iataCode":"CJU","cityName":"제주"},"pkgtour":{"productList":[{"productId":"118-20220726"}]}},"domesticArticle":{"categoryList":["all","shopping","tour","food","tv","basic","course"]}},"dataUpdateCount":1,"dataUpdatedAt":1658715633521,"error":null,"errorUpdateCount":0,"errorUpdatedAt":0,"fetchFailureCount":0,"fetchMeta":null,"isFetching":false,"isInvalidated":false,"isPaused":false,"status":"success"},"queryKey":["COMMON","14"],"queryHash":"[\"COMMON\",\"14\"]"},{"state":{"data":{"domesticGeoInfo":{"rcode":"14","nameKo":"제주","descendants":[{"exposeTitle":"제주특별자치도 제주시","rcode":"14110","name":"제주시"},{"exposeTitle":"제주특별자치도 서귀포시","rcode":"14130","name":"서귀포시"}],"dictInfo":{"description":"한국·중국·일본 등 극동 지역의 중앙부에 있어 지정학적으로도 중요하며, 도 전체가 바다로 둘러싸였다. 수리적(數理的)으로는 동경 126°08'∼126°58', 북위 33°06'∼34°00'에 위치한다. 북단은 북위 34°00'의 제주시 추자면 대서리이며, 남단은 북위 33°06'의 서귀포시 대정읍 마라도다. 한국 최남단에 있는 도로서, 제주도를 포함해 9개의 유인도와 55개의 무인도로 이루어졌다. 이 가운데 유인도는 우도·상추자도·하추자도·비양도·횡간도·추포도·가파도·마라도이다. 남북 간의 거리가 약 31㎞, 동서간의 거리가 약 73㎞로 동서로 가로놓인 모양이다. 러시아·중국 등의 대륙과 일본·동남아 등지를 연결하는 요충지이며, 천혜의 자연경관이 수려한 세계적인 휴양관광지다."},"homepage":"https://www.visitjeju.net/kr","homepageTitle":"비짓제주","mapLinkPc":"https://map.naver.com/v5/search/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84","mapLinkMo":"https://m.map.naver.com/viewer/map.naver?pinTitle=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84&lng=126.49827&lat=33.488994&rcode=14&isShowPolygon=true&isDetailAddress=false","keywords":{"hotTopic":["흑돼지","오메기떡","미로공원","고등어회","전복뚝배기","성게미역국","돔베고기","갈치회","카약","유채꽃밭","감귤체험","낚시체험","사진찍기좋은"]},"covid":{"key":"제주","diff":null,"url":"https://jeju.go.kr/covid19.jsp"},"weatherInfo":{"today":{"weatherCode":"5","weatherText":"구름많음","currTemperature":27.5,"feelTemperature":29.5,"minTemperature":24,"maxTemperature":29,"diffTemperature":-0.4,"rainfall":{"rainProb":"","rainAmt":0,"todayRainAmt":0,"snowAmt":"-","minRainAmt":0,"maxRainAmt":0},"dust":{"airPollutionData":{"value":"17","legend":"좋음","todayAmValue":"좋음","todayPmValue":"좋음"},"pm25Data":{"value":"11","legend":"좋음","todayAmValue":"좋음","todayPmValue":"좋음"}},"o3":{"legend1hr":"보통","legend":"보통","value":"0.052"}},"weekWeather":[{"day":"월","date":"07.25.","minTemperature":24,"maxTemperature":2 ...
#   naver.search.ext.travelSearch.__CONTEXT__ = {"placeId":"14","ptnCode":"info","where":"nexearch","nscs":"0"};
#   </script>
# <script>
#     (function (urls) {
#       var newUrls = urls;
#       if (!(newUrls && newUrls.length > 0)) return;
#       for (var i = 0; i < newUrls.length; i++) {
#         window.nhn.common.load_js(newUrls[i], function () {}, false);
#       }
#     })(['https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/runtime~main-bundle-145de005.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/main-bundle-cc2d5eb9.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/components-mainContainer-bundle-1e013ce3.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/13-bundle-5b52c651.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/12-bundle-339f9425.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/14-bundle-4805fcf3.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/220721-170537-d63338f/dist/web/pages-info-bundle-24e0959d.js']);
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[1,13,12,14,4]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["components-mainContainer","pages-info"]}</script>
# </div>
# <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
# <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/js/220616/power_link_for_you_responsive_pc.js?o=search"></script>
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220622/css/nx_powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">제주도</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=eRgQyEt89nTMH0Pr4jDPks9_...-...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_price type_img" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=lHleR3OTB2dyVzbZWCnDBP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;d='+urlencode('http://smartstore.naver.com/carpick')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMTAzMTJfMjcg/MDAxNjE1NTI1MTAyNDYz.L0Xz03y9DJlzZ74t4eZHQHRmGBbevr4l4X9Xy4o0fz8g.QkPXIuEqP8UpAfDBSAiI6vTlrbNW6Ucr-esXAmqkkycg.JPEG/1314938-8998e50d-2b36-4063-b4f9-e4a647877c2d.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=aw/y/RmbHF0qn5NQbP29V////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;d=' + urlencode('http://smartstore.naver.com/carpick') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">48시간프리패스 제주투어패스</span><span class="lnk_tit">제주 여행의 끝판왕!</span><span class="lnk_tit">누적 191만건 돌파!</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=aw/y/RmbHF0qn5NQbP29V////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;d='+urlencode('http://smartstore.naver.com/carpick')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/carpick</a>
# </div>
# <p class="ad_dsc">
#
#               제주 인기 핫플레이스부터 나만 알고싶은 숨은 명소까지 48시간 무제한 이용 가능!
#
#             </p>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=uke2Qre/lF6u2pYBHWG2t////w==..." onclick="return goOtherCR(this,'a=pwl_nop.pricelink1&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;d='+urlencode('http://smartstore.naver.com/carpick')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">22,500원부터</span>
# <div class="txt">
# <span class="txt_inner">48시간 제주투어패스</span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=DMk4WGFMv8zCMTCSp+tijf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.pricelink2&amp;r=1&amp;i=nad-a001-01-000000146582007&amp;d='+urlencode('http://smartstore.naver.com/carpick')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">9,800원부터</span>
# <div class="txt">
# <span class="txt_inner">타임제로 자유이용권</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=QCHIraKXj5TAzVlRuaracf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMTA0MTVfMTk5/MDAxNjE4NDY4NjgxMjU2.znpbHXqI5NQc-x1ABazWgQF2Xkq2NN9F01-FXsZmD1kg.Yvhhpw3h1g7ZhHiiz8gXo60b1zXksdST9HeodGOO3kAg.PNG/1186320-1a26cbe0-a774-4edf-a94f-573712cd3b10.png?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=+Vt2LTIF0WF7MSJu/+ANNP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d=' + urlencode('http://www.coupang.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">쿠팡 제주도</span><span class="lnk_tit">와우회원 할인</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=+Vt2LTIF0WF7MSJu/+ANNP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.coupang.com</a>
# </div>
# <p class="ad_dsc">
# <strong class="hl">제주도</strong>, 숙박여행, 항공권, 렌터카, 쿠팡으로 떠나는 특별한 휴가!
#
#             </p>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=R5HUKihPQCKGHj/ZGQpOyP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">쿠팡여행</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=dLb1qwVKbRzubIBdWufKMv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">로켓배송</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=CsZxQmqZkx5F0/NSEaFJeP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">로켓프레시</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=u/ldKPtBu17+tDbWclWkrv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=2&amp;i=nad-a001-01-000000193843104&amp;d='+urlencode('http://www.coupang.com')+'&amp;u='+urlencode(this.href));" target="_blank">골드박스</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_desc type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=OVtFW7Cfy5eb/pb2IPi31v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000178135752&amp;d='+urlencode('http://jejudaol.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA1MTFfMTE4/MDAxNjUyMjUwNDA3ODE0.WBRrF3J5engRXsmSMQd0eFaEFCxr54rx72rljPBSXF0g.ClkDTyEsUbjnOpALSCCg0L62MA4mJbuwdz5qwYgSVV0g.PNG/2141370-33ab6df4-fec4-4d8a-9cfa-77191a0f9cd7.png?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=V3ZOakyZ7QXlxOfS869CHf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000178135752&amp;d=' + urlencode('http://jejudaol.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">제주도여행 전문 제주다올투어</span><span class="lnk_tit">여행무료상담, 카드결제가능!</span><span class="lnk_tit">여행패키지 상담시 추가할인!</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_talktalk" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 톡톡</span>
# <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.talktalk&amp;r=3&amp;i=nad-a001-01-000000178135752&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
# <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_nad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=V3ZOakyZ7QXlxOfS869CHf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000178135752&amp;d='+urlencode('http://jejudaol.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">jejudaol.co.kr</a>
# </div>
# <p class="ad_dsc">
# <strong class="hl">제주도</strong>여행 특급할인! 초특가할인+무료친절상담+카드결제가능! 렌트카/항공권/숙박OK <strong class="hl">제주도</strong> 여행 아직도 고민중이신가요? 제주다올투어에서 해결해드립니다!
#
#
#             </p>
# <p class="ad_dsc promotion">
# <em class="point">이벤트</em>
#               렌트카/항공권/숙박 OK!
#             </p>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=60YdJTtcPz/9JXce4h3me////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d='+urlencode('http://www.hotelscombined.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA2MjhfMjcy/MDAxNjU2Mzk2MDQ4NDQ1.H0ikMvD2E50yV1CfK1tMkSCk2Pt5ps3P_NjVL1E3faEg.AH7GX3KKmDDBU8L0Wm54hbhZ_akLik3AhIY4K4noqmsg.JPEG/513123-b2edbedb-050a-4fea-8d1b-7cf34952e103.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=GXgTArqOpNKQwt8gKUhw5P///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d=' + urlencode('http://www.hotelscombined.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">제주도,호텔스컴바인</span><span class="lnk_tit">Npay 5% 적립혜택</span><span class="lnk_tit">인기숙소 최저가로 예약</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=GXgTArqOpNKQwt8gKUhw5P///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d='+urlencode('http://www.hotelscombined.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.hotelscombined.co.kr</a>
# </div>
# <p class="ad_dsc">
#
#               기다리던 여름휴가! 호텔스컴바인과 함께 최저가 호텔예약으로 기분좋은 여행 시작!
#
#             </p>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Avxg2Gbs8nLHUFtXsTNIlf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d='+urlencode('http://www.hotelscombined.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">N페이 5%</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=n5xmN6FjfnLqF9oqDCiRRv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d='+urlencode('http://www.hotelscombined.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">추가 이벤트</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=jTfdr2+a2bW6sFhmb/eIR////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000185625513&amp;d='+urlencode('http://www.hotelscombined.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">최대5%할인</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_desc type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=CxK4bWB/4mQhPbiX4VHM8P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000192514304&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjAxMjFfOCAg/MDAxNjQyNzU0MTU5NDQ3.IgUUNBFWeKjP9l-4kJ3jmSgiF96Im5NXfGPbNwDUQN4g.7RcMRUjEkdHz0D5EoHGt4Njj3qhdcSth6wxkiAz1hGUg.JPEG/570523-12e71280-f57e-4aaf-ad73-03979b95d385.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=YMnFJfjZzVkj7h1nX68a9////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000192514304&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">티몬 제주도</span><span class="lnk_tit">쇼핑+결제+웰컴쿠폰 3종세트</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000192514304&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=YMnFJfjZzVkj7h1nX68a9////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000192514304&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# </div>
# <p class="ad_dsc">
#
#               여행은 역시 티몬, 성수기 숙박 6%추가 즉시할인+매일 새로운 특가 오픈까지!
#
#             </p>
# <p class="ad_dsc promotion">
# <em class="point">할인</em>
#               티비온 셀럽추천+꿀딜까지!
#             </p>
# </div>
# </li>
# <li class="lst type_more type_subtitle" num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=/jDhW00Oe6WbTu3ayjFnF////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000182263064&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">G마켓 제주도</span><span class="lnk_tit">누구나 10% 할인!</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=/jDhW00Oe6WbTu3ayjFnF////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000182263064&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.gmarket.co.kr</a>
# </div>
# <p class="ad_dsc">
# <strong class="hl">제주도</strong> 멤버십 유니버스의 시작! 스마일클럽 12%쿠폰x4장 지급!
#
#             </p>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=Vnc8aI6kGxCXnTpPq2V/Yv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=7&amp;i=nad-a001-01-000000174514966&amp;d='+urlencode('https://sorangstudio.modoo.at/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA2MTZfMTI5/MDAxNjU1MzU2Mjk5OTg2.P-vmtxGMQgY_SQhTD_hLUvsD4a_EWWRfT8PNbgrpGDog.XC8BGbewJUo1yRLyusfBWJmGLf3sK63ExF00WqyaSP0g.JPEG/2169861-c59c8ff5-917a-4efd-92af-1353d8c7a80b.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=OY2X3dtb83CqJY7WHsiWrv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000174514966&amp;d=' + urlencode('https://sorangstudio.modoo.at/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">제주도소랑사진관</span><span class="lnk_tit">흑백/컬러/셀프/작가촬영</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# ...
# <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <script type="text/javascript">
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">제주도</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=WAADmapjFJeQ2VRazogqZsEkjwxYbwA3pHTE--...">
# <ul class="lst_type">
# <li class="lst" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=ouVoYAE5H0t4bbQI3YqoYP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000078761506&amp;d=' + urlencode('http://www.agoda.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">최저가호텔예약은 역시 아고다</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=1&amp;i=nad-a001-01-000000078761506&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ouVoYAE5H0t4bbQI3YqoYP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000078761506&amp;d='+urlencode('http://www.agoda.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.agoda.com</a>
# </div>
# <p class="ad_dsc">
#
#               전 국민이 선택한 호텔 예약 사이트 아고다! 이달의 할인쿠폰 즉시 발급
#
#             </p>
# </div>
# </li>
# <li class="lst" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=fQSvRaM3BqSmz+AvKZtxUP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000182278079&amp;d=' + urlencode('http://www.auction.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">옥션 제주도</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=fQSvRaM3BqSmz+AvKZtxUP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000182278079&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.auction.co.kr</a>
# </div>
# <p class="ad_dsc">
# <strong class="hl">제주도</strong> 멤버십 유니버스의 시작! 스마일클럽 가입즉시 3만5천원 캐시 지급!
#
#             </p>
# </div>
# </li>
# <li class="lst" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=mvhMJxtGJ7MGM2ZMdevI4////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000190758027&amp;d=' + urlencode('http://www.11st.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">11번가 제주도</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=mvhMJxtGJ7MGM2ZMdevI4////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000190758027&amp;d='+urlencode('http://www.11st.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.11st.co.kr</a>
# </div>
# <p class="ad_dsc">
# <strong class="hl">제주도</strong>, 누구나 쿠폰 올클! 최대 11,000원 쿠폰+카드사 ~12%할인
#
#             </p>
# </div>
# </li>
# <li class="lst" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=ROPynrlZmH2bI5p40D/MhP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000121036829&amp;d=' + urlencode('https://blog.naver.com/upjwup') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">동부회원권 중부지사 이진우</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ROPynrlZmH2bI5p40D/MhP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000121036829&amp;d='+urlencode('https://blog.naver.com/upjwup')+'&amp;u='+urlencode(this.href));" target="_blank">blog.naver.com/upjwup</a>
# </div>
# <p class="ad_dsc">
#
#               믿을수있는 회원권거래소/ 오랜경력의 전문딜러 / 신속 정확한 매물체크 / 빠른거래
#
#             </p>
# </div>
# </li>
# <li class="lst" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=sWFX+8pKuDRZH6IZR3ACW////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000075588129&amp;d=' + urlencode('http://www.instagram.com/jeju_dongbaek_kitchen') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">제주 동백키친</span>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=sWFX+8pKuDRZH6IZR3ACW////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000075588129&amp;d='+urlencode('http://www.instagram.com/jeju_dongbaek_kitchen')+'&amp;u='+urlencode(this.href));" target="_blank">www.instagram.com/jeju_dongbaek_kitchen</a>
# </div>
# <p class="ad_dsc">
#
#               제주 로컬감성의 파스타&amp;필라프 전문점.
#
#             </p>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;referenceId=hW3%2FPsprvxZssaBDv9VssssstO0-024935" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_nad"></i></a>
# </div>
# </div>
# </div>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=15&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> <section class="sc_new sp_nkeyword" id="nx_footer_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a class="api_link_help" href="https://help.naver.com/support/alias/search/word/word_1.naver" onclick="return  ...

# %%
import re

data = str(data)
data_1 = re.findall('[가-힣]+',data)
data_1
# Out:
# ['제주도',
#  '네이버',
#  '통합검색',
#  '제주도',
#  '의',
#  '네이버',
#  '통합검색',
#  '결과입니다',
#  '제주도',
#  '의',
#  '네이버',
#  '통합검색',
#  '결과입니다',
#  '제주도',
#  '네이버',
#  '통합검색',
#  '제주도',
#  '제주도',
#  '메뉴',
#  '영역으로',
#  '바로가기',
#  '본문',
#  '영역으로',
#  '바로가기',
#  '검색',
#  '검색어를',
#  '입력해',
#  '주세요',
#  '제주도',
#  '제주도',
#  '한글',
#  '입력기',
#  '네트워크',
#  '상태가',
#  '안',
#  '좋아',
#  '한영입력기를',
#  '불러오지',
#  '못했습니다',
#  '잠시',
#  '후',
#  '다시',
#  '시도해',
#  '주세요',
#  '자동완성',
#  '레이어',
#  '최근검색어',
#  '전체삭제',
#  '삭제',
#  '검색어',
#  '저장',
#  '기능이',
#  '꺼져',
#  '있습니다',
#  '설정이',
#  '초기화',
#  '된다면',
#  '도움말',
#  '을',
#  '확인해주세요',
#  '최근',
#  '검색어',
#  '내역이',
#  '없습니다',
#  '설정이',
#  '초기화',
#  '된다면',
#  '도움말',
#  '을',
#  '확인해주세요',
#  '도움말',
#  '자동저장',
#  '끄기',
#  '회차',
#  '당첨번호',
#  '추첨',
#  '지급기한',
#  '년',
#  '원',
#  '바로가기',
#  '추가',
#  '추가',
#  '추가',
#  '자세히보기',
#  '관심사를',
#  '반영한',
#  '컨텍스트',
#  '자동완성',
#  '도움말',
#  '컨텍스트',
#  '자동완성',
#  '컨텍스트',
#  '자동완성',
#  '설정은',
#  '해당기기',
#  '브라우저',
#  '에',
#  '저장됩니다',
#  '자세히',
#  '동일한',
#  '시간대',
#  '연령',
#  '남녀별',
#  '사용자',
#  '그룹의',
#  '관심사에',
#  '맞춰',
#  '자동완성을',
#  '제공합니다',
#  '로그인',
#  '자세히',
#  '컨텍스트',
#  '자동완성',
#  '레이어',
#  '닫기',
#  '도움말',
#  '신고',
#  '자동완성',
#  '끄기',
#  '검색',
#  '통합',
#  '지도',
#  '이미지',
#  '뉴스',
#  '지식',
#  '인플루언서',
#  '동영상',
#  '쇼핑',
#  '어학사전',
#  '더보기',
#  '도서',
#  '뮤직',
#  '지식백과',
#  '오디오클립',
#  '학술정보',
#  '검색옵션',
#  '통합검색',
#  '공유',
#  '통합검색',
#  '제주도',
#  '통합검색',
#  '결과',
#  '제주도',
#  '검색옵션',
#  '닫기',
#  '정렬',
#  '관련도순',
#  '최신순',
#  '기간',
#  '전체',
#  '시간',
#  '일',
#  '주',
#  '개월',
#  '개월',
#  '개월',
#  '년',
#  '직접입력',
#  '옵션',
#  '펼치기',
#  '접기',
#  '기간',
#  '설정시작',
#  '기간',
#  '설정끝',
#  '년',
#  '월',
#  '일',
#  '적용',
#  '옵션초기화',
#  '검색옵션',
#  '가이드',
#  '의',
#  '경로',
#  '지정',
#  '은',
#  '의',
#  '별로',
#  '호출해야함',
#  '클릭로그',
#  '호출',
#  '제주',
#  '특별자치도청',
#  '위치',
#  '소개',
#  '정보공개',
#  '도정뉴스',
#  '소통',
#  '참여',
#  '제주',
#  '뉴스',
#  '생활민원',
#  '여권발급',
#  '문화',
#  '제주도',
#  '관광',
#  '산업경제',
#  '복지',
#  '여성',
#  '정보',
#  '수록',
#  '사이트내',
#  '검색',
#  '검색',
#  '이',
#  '사이트에서',
#  '다시',
#  '검색',
#  '이',
#  '사이트',
#  '제외하고',
#  '다시',
#  '검색',
#  '검색어를',
#  '입력해주세요',
#  '블로그',
#  '카카오스토리',
#  '인스타그램',
#  '페이스북',
#  '트위터',
#  '유튜브',
#  '네이버',
#  '포스트',
#  '최신',
#  '콘텐츠',
#  '노출기준',
#  '이',
#  '정보가',
#  '표시된',
#  '이유',
#  '사용자',
#  '선호도',
#  '및',
#  '최신',
#  '게시글',
#  '존재',
#  '여부',
#  '인증',
#  '여부',
#  '등',
#  '다양한',
#  '요소들을',
#  '고려하여',
#  '연관',
#  '채널의',
#  '최신',
#  '게시물을',
#  '노출합니다',
#  '일부',
#  '웹사이트',
#  '대상으로',
#  '공지사항',
#  '게시글들을',
#  '자동으로',
#  '수집하여',
#  '노출합니다',
#  '네이버',
#  '고객센터',
#  '정보확인',
#  '레이어',
#  '닫기',
#  '제주특별자치도청',
#  '년',
#  '월',
#  '국제크루즈',
#  '선석배정',
#  '변경내역',
#  '알림',
#  '공지',
#  '시간',
#  '전',
#  '제주특별자치도청',
#  '일일',
#  '소방종합',
#  '상황보고',
#  '년',
#  '월',
#  '일',
#  '공지',
#  '시간',
#  '전',
#  '제주특별자치도청',
#  '기상상황',
#  '월요일',
#  '공지',
#  '시간',
#  '전',
#  '제주특별자치도',
#  '네이버',
#  '동영상',
#  '년',
#  '복권기금사업',
#  '시간',
#  '이내',
#  '공식',
#  '제주특별자치도',
#  '포스트',
#  '오영훈',
#  '지사',
#  '청년들이',
#  '다시',
#  '도전할',
#  '수',
#  '있도록',
#  '조력자',
#  '역할하겠다',
#  '시간',
#  '이내',
#  '트위터',
#  '오영훈',
#  '지사',
#  '청년들이',
#  '다시',
#  '도전할',
#  '수',
#  '있도록',
#  '조력자',
#  '역할하겠다',
#  '일',
#  '오후',
#  '도청',
#  '탐라홀서',
#  '제주청년',
#  '갭이어',
#  '프로그램',
#  '오리엔테이션',
#  '제주도청',
#  '보도자료',
#  '오영훈',
#  '제주도지사',
#  '갭이어',
#  '청년정책',
#  '제주형',
#  '청년보장제',
#  '트위터',
#  '시간',
#  '이내',
#  '댓글',
#  '리트윗',
#  '좋아요',
#  '메세지',
#  '제주특별자치도',
#  '네이버',
#  '동영상',
#  '오영훈',
#  '지사',
#  '청년들이',
#  '다시',
#  '도전할',
#  '수',
#  '있도록',
#  '조력자',
#  '역할하겠다',
#  '시간',
#  '전',
#  '공식',
#  '제주특별자치도',
#  '블로그',
#  '제주도',
#  '상반기',
#  '지방재정',
#  '최우수',
#  '광역자치단체',
#  '선정',
#  '시간',
#  '전',
#  '공식',
#  '제주특별자치도',
#  '블로그',
#  '제주',
#  '최고의',
#  '자연',
#  '휴양',
#  '공간',
#  '제주곶자왈도립공원',
#  '어제',
#  '트위터',
#  '치유와',
#  '휴식을',
#  '위한',
#  '공간',
#  '국내',
#  '최초',
#  '곶자왈에',
#  '조성된',
#  '교래자연휴양림',
#  '야영장',
#  '생태체험관',
#  '등',
#  '여러',
#  '가지',
#  '시설도',
#  '갖추고',
#  '있어요',
#  '몸과',
#  '마음의',
#  '휴식을',
#  '찾아',
#  '떠나보세요',
#  '제주',
#  '교래자연휴양림',
#  '제주교래자연휴양림',
#  '자연휴양림',
#  '제주야영장',
#  '제주여행',
#  '트위터',
#  '어제',
#  '댓글',
#  '리트윗',
#  '좋아요',
#  '메세지',
#  '공식',
#  '제주특별자치도',
#  '블로그',
#  '오영훈',
#  '지사',
#  '청년들이',
#  '다시',
#  '도전할',
#  '수',
#  '있도록',
#  '조력자',
#  '역할하겠다',
#  '일',
#  '전',
#  '제주특별자치도',
#  '네이버',
#  '동영상',
#  '오영훈',
#  '지사',
#  '도내',
#  '의료기관장',
#  '코로나',
#  '대응체계',
#  '정비',
#  '일',
#  '전',
#  '이전',
#  '다음',
#  '의',
#  '경로',
#  '지정',
#  '은',
#  '의',
#  '별로',
#  '호출해야함',
#  '은',
#  '의',
#  '별로',
#  '호출해야함',
#  '클래스',
#  '추가',
#  '후',
#  '모듈을',
#  '초기화',
#  '루트',
#  '요소',
#  '사이트',
#  '내',
#  '검색',
#  '버튼',
#  '클릭',
#  '이벤트',
#  '등록',
#  '사이트',
#  '내',
#  '검색',
#  '버튼',
#  '클릭',
#  '이벤트',
#  '등록',
#  '제주특별자치도',
#  '다른지역보기',
#  '전체',
#  '여행콘텐츠',
#  '상품예약',
#  '도시정보',
#  '도시정보',
#  '한국',
#  '중국',
#  '일본',
#  '등',
#  '극동',
#  '지역의',
#  '중앙부에',
#  '있어',
#  '지정학적으로도',
#  '중요하며',
#  '도',
#  '전체가',
#  '바다로',
#  '둘러싸였다',
#  '수리적',
#  '으로는',
#  '동경',
#  '북위',
#  '에',
#  '위치한다',
#  '북단은',
#  '북위',
#  '의',
#  '제주시',
#  '추자면',
#  '대서리이며',
#  '남단은',
#  '북위',
#  '의',
#  '서귀포시',
#  '대정읍',
#  '마라도다',
#  '한국',
#  '최남단에',
#  '있는',
#  '도로서',
#  '제주도를',
#  '포함해',
#  '개의',
#  '유인도와',
#  '개의',
#  '무인도로',
#  '이루어졌다',
#  '이',
#  '가운데',
#  '유인도는',
#  '우도',
#  '상추자도',
#  '하추자도',
#  '비양도',
#  '횡간도',
#  '추포도',
#  '가파도',
#  '마라도이다',
#  '남북',
#  '간의',
#  '거리가',
#  '약',
#  '동서간의',
#  '거리가',
#  '약',
#  '로',
#  '동서로',
#  '가로놓인',
#  '모양이다',
#  '러시아',
#  '중국',
#  '등의',
#  '대륙과',
#  '일본',
#  '동남아',
#  '등지를',
#  '연결하는',
#  '요충지이며',
#  '천혜의',
#  '자연경관이',
#  '수려한',
#  '세계적인',
#  '휴양관광지다',
#  '관련',
#  '비짓제주',
#  '지도',
#  '행정구역',
#  '제주시',
#  '서귀포시',
#  '날씨정보',
#  '구름많음',
#  '구름많음',
#  '어제보다',
#  '낮아요',
#  '체감온도',
#  '미세먼지',
#  '좋음',
#  '초미세먼지',
#  '좋음',
#  '오존지수',
#  '보통',
#  '월',
#  '구름많음',
#  '낮',
#  '화',
#  '구름많음',
#  '낮',
#  '수',
#  '구름많음',
#  '낮',
#  '목',
#  '구름많음',
#  '낮',
#  '금',
#  '흐림',
#  '토',
#  '구름많음',
#  '낮',
#  '일',
#  '구름많음',
#  '낮',
#  '월',
#  '흐림',
#  '화',
#  '흐림',
#  '수',
#  '흐림',
#  '흑돼지',
#  '오메기떡',
#  '미로공원',
#  '고등어회',
#  '전복뚝배기',
#  '성게미역국',
#  '돔베고기',
#  '갈치회',
#  '제주',
#  '제주특별자치도',
#  '숙소',
#  '호텔',
#  '제주',
#  '제주특별자치도',
#  '강원도',
#  '강원도',
#  '부산',
#  '부산광역시',
#  '서울',
#  '서울특별시',
#  '경기도',
#  '경기도',
#  '인천',
#  '인천광역시',
#  '충북',
#  '충청북도',
#  '충남',
#  '충청남도',
#  '경북',
#  '경상북도',
#  '경남',
#  '경상남도',
#  '전북',
#  '전라북도',
#  '전남',
#  '전라남도',
#  '롯데',
#  '호텔',
#  '제주',
#  '더큐브',
#  '리조트',
#  '제주',
#  '제이앤클로이',
#  '다인리조트',
#  '제주',
#  '제주',
#  '제주특별자치도',
#  '제주시',
#  '제주시',
#  '제주특별자치도',
#  '서귀포시',
#  '서귀포시',
#  '한국',
#  '중국',
#  '일본',
#  '등',
#  '극동',
#  '지역의',
#  '중앙부에',
#  '있어',
#  '지정학적으로도',
#  '중요하며',
#  '도',
#  '전체가',
#  '바다로',
#  '둘러싸였다',
#  '수리적',
#  '으로는',
#  '동경',
#  '북위',
#  '에',
#  '위치한다',
#  '북단은',
#  '북위',
#  '의',
#  '제주시',
#  '추자면',
#  '대서리이며',
#  '남단은',
#  '북위',
#  '의',
#  '서귀포시',
#  '대정읍',
#  '마라도다',
#  '한국',
#  '최남단에',
#  '있는',
#  '도로서',
#  '제주도를',
#  '포함해',
#  '개의',
#  '유인도와',
#  '개의',
#  '무인도로',
#  '이루어졌다',
#  '이',
#  '가운데',
#  '유인도는',
#  '우도',
#  '상추자도',
#  '하추자도',
#  '비양도',
#  '횡간도',
#  '추포도',
#  '가파도',
#  '마라도이다',
#  '남북',
#  '간의',
#  '거리가',
#  '약',
#  '동서간의',
#  '거리가',
#  '약',
#  '로',
#  '동서로',
#  '가로놓인',
#  '모양이다',
#  '러시아',
#  '중국',
#  '등의',
#  '대륙과',
#  '일본',
#  '동남아',
#  '등지를',
#  '연결하는',
#  '요충지이며',
#  '천혜의',
#  '자연경관이',
#  '수려한',
#  '세계적인',
#  '휴양관광지다',
#  '비짓제주',
#  '흑돼지',
#  '오메기떡',
#  '미로공원',
#  '고등어회',
#  '전복뚝배기',
#  '성게미역국',
#  '돔베고기',
#  '갈치회',
#  '카약',
#  '유채꽃밭',
#  '감귤체험',
#  '낚시체험',
#  '사진찍기좋은',
#  '제주',
#  '구름많음',
#  '좋음',
#  '좋음',
#  '좋음',
#  '좋음',
#  '좋음',
#  '좋음',
#  '보통',
#  '보통',
#  '월',
#  '오전',
#  '구름많음',
#  '구름많음',
#  '오후',
#  '맑음',
#  '맑음',
#  '화',
#  '오전',
#  '맑음',
#  '맑음',
#  '오후',
#  '구름많음',
#  '구름많음',
#  '수',
#  '오전',
#  '구름많음',
#  '구름많음',
#  '오후',
#  '맑음',
#  '맑음',
#  '목',
#  '오전',
#  '구름많음',
#  '구름많음',
#  '오후',
#  '구름많음',
#  '구름많음',
#  '금',
#  '오전',
#  '흐림',
#  '흐림',
#  '오후',
#  '구름많음',
#  '구름많음',
#  '토',
#  '오전',
#  '구름많음',
#  '구름많음',
#  '오후',
#  '구름많음',
#  '구름많음',
#  '일',
#  '오전',
#  '구름많음',
#  '구름많음',
#  '오후',
#  '구름많음',
#  '구름많음',
#  '월',
#  '오전',
#  '흐림',
#  '흐림',
#  '오후',
#  '흐림',
#  '흐림',
#  '화',
#  '오전',
#  '흐림',
#  '흐림',
#  '오후',
#  '흐림',
#  '흐림',
#  '수',
#  '오전',
#  '흐림',
#  '흐림',
#  '오후',
#  '흐림',
#  '흐림',
#  '파워링크',
#  '제주도',
#  '관련',
#  '광고입니다',
#  '이',
#  '광고가',
#  '표시된',
#  '이유',
#  '이',
#  '광고가',
#  '표시된',
#  '이유',
#  '광고',
#  '노출기준은',
#  '검색어에',
#  '대한',
#  '연관성과',
#  '광고주의',
#  '입찰가이며',
#  '이미지',
#  '등',
#  '추가',
#  '링크는',
#  '등록한',
#  '경우에만',
#  '기준에',
#  '따라',
#  '노출됩니다',
#  '도움말',
#  '안내',
#  '레이어',
#  '닫기',
#  '등록',
#  '안내',
#  '링크이미지',
#  '시간프리패스',
#  '제주투어패스',
#  '제주',
#  '여행의',
#  '끝판왕',
#  '누적',
#  '만건',
#  '돌파',
#  '광고',
#  '네이버페이',
#  '네이버페이',
#  '네이버',
#  '아이디',
#  '하나로',
#  '간편구매',
#  '서비스',
#  '보기',
#  '제주',
#  '인기',
#  '핫플레이스부터',
#  '나만',
#  '알고싶은',
#  '숨은',
#  '명소까지',
#  '시간',
#  '무제한',
#  '이용',
#  '가능',
#  '원부터',
#  '시간',
#  '제주투어패스',
#  '원부터',
#  '타임제로',
#  '자유이용권',
#  '링크이미지',
#  '쿠팡',
#  '제주도',
#  '와우회원',
#  '할인',
#  '광고',
#  '제주도',
#  '숙박여행',
#  '항공권',
#  '렌터카',
#  '쿠팡으로',
#  '떠나는',
#  '특별한',
#  '휴가',
#  '쿠팡여행',
#  '로켓배송',
#  '로켓프레시',
#  '골드박스',
#  '링크이미지',
#  '제주도여행',
#  '전문',
#  '제주다올투어',
#  '여행무료상담',
#  '카드결제가능',
#  '여행패키지',
#  '상담시',
#  '추가할인',
#  '광고',
#  '네이버',
#  '톡톡',
#  '네이버톡톡으로',
#  '상담이',
#  '가능한',
#  '사이트입니다',
#  '톡톡',
#  '서비스',
#  '보기',
#  '제주도',
#  '여행',
#  '특급할인',
#  '초특가할인',
#  '무료친절상담',
#  '카드결제가능',
#  '렌트카',
#  '항공권',
#  '숙박',
#  '제주도',
#  '여행',
#  '아직도',
#  '고민중이신가요',
#  '제주다올투어에서',
#  '해결해드립니다',
#  '이벤트',
#  '렌트카',
#  '항공권',
#  '숙박',
#  '링크이미지',
#  '제주도',
#  '호텔스컴바인',
#  '적립혜택',
#  '인기숙소',
#  '최저가로',
#  '예약',
#  '광고',
#  '네이버',
#  '로그인',
#  '네이버',
#  '아이디로',
#  '로그인이',
#  '가능합니다',
#  '서비스',
#  '자세히',
#  '보기',
#  '기다리던',
#  '여름휴가',
#  '호텔스컴바인과',
#  '함께',
#  '최저가',
#  '호텔예약으로',
#  '기분좋은',
#  '여행',
#  '시작',
#  '페이',
#  '추가',
#  '이벤트',
#  '최대',
#  '할인',
#  '링크이미지',
#  '티몬',
#  '제주도',
#  '쇼핑',
#  '결제',
#  '웰컴쿠폰',
#  '종세트',
#  '광고',
#  '네이버',
#  '로그인',
#  '네이버',
#  '아이디로',
#  '로그인이',
#  '가능합니다',
#  '서비스',
#  '자세히',
#  '보기',
#  '여행은',
#  ...]

# %%
from konlpy.tag import Okt

okt = Okt()
morph = okt.pos(data)  # pos 단어와 품사를 뽑아줌
noun_list = []
for word, tag in morph:
    if (tag=='Noun') & (len(word) > 1): # Noun이고 단어 1글자 이상인것 뽑아줌 의미있눈거! 한글자는 조사자나
        noun_list.append(word)
#print(morph)
print(noun_list)
# Out:
# ['제주도', '네이버', '통합', '검색', '제주도', '네이버', '통합', '검색', '결과', '제주도', '네이버', '통합', '검색', '결과', '제주도', '네이버', '통합', '검색', '제주도', '제주도', '메뉴', '영역', '바로가기', '본문', '영역', '바로가기', '검색', '검색어', '입력', '제주도', '제주도', '한글', '입력기', '네트워크', '상태', '입력기', '잠시', '다시', '시도', '자동', '완성', '레이어', '최근', '검색어', '전체', '삭제', '삭제', '검색어', '저장', '기능', '설정', '초기', '도움말', '확인', '최근', '검색어', '설정', '초기', '도움말', '확인', '도움말', '자동', '저장', '회차', '당첨번호', '추첨', '지급', '기한', '바로가기', '추가', '추가', '추가', '보기', '관심사', '반영', '텍스트', '자동', '완성', '도움말', '텍스트', '자동', '완성', '텍스트', '자동', '완성', '설정', '해당', '기기', '브라우저', '저장', '시간대', '연령', '남녀', '사용자', '그룹', '관심사', '자동', '완성', '제공', '로그인', '텍스트', '자동', '완성', '레이어', '도움말', '신고', '자동', '완성', '검색', '통합', '지도', '이미지', '뉴스', '지식', '플루', '동영상', '쇼핑', '어학', '사전', '보기', '도서', '뮤직', '지식', '오디오', '클립', '학술', '정보', '검색', '옵션', '통합', '검색', '공유', '통합', '검색', '제주도', '통합', '검색', '결과', '제주도', '검색', '옵션', '정렬', '관련', '최신', '기간', '전체', '개월', '개월', '개월', '직접', '입력', '옵션', '접기', '기간', '설정', '시작', '기간', '설정', '적용', '옵션', '초기', '검색', '옵션', '가이드', '경로', '지정', '별로', '호출', '클릭', '로그', '호출', '제주', '특별자치도', '위치', '소개', '정보공개', '도정', '뉴스', '소통', '참여', '제주', '뉴스', '생활', '민원', '여권', '발급', '문화', '제주도', '관광', '산업', '경제', '복지', '여성', '정보', '수록', '사이트', '검색', '검색', '사이트', '다시', '검색', '사이트', '제외', '다시', '검색', '검색어', '입력', '블로그', '카카오스토리', '인스타그램', '페이스북', '트위터', '유튜브', '네이버', '포스트', '최신', '콘텐츠', '노출', '기준', '정보', '표시', '이유', '사용자', '선호', '최신', '게시', '존재', '여부', '인증', '여부', '요소', '고려', '연관', '채널', '최신', '게시', '일부', '웹사이트', '대상', '공지', '사항', '게시', '자동', '수집', '네이버', '고객', '센터', '정보', '확인', '레이어', '제주', '특별자치도', '국제', '크루즈', '배정', '변경', '알림', '공지', '제주', '특별자치도', '일일', '소방', '종합', '상황보고', '공지', '제주', '특별자치도', '기상', '상황', '월요일', '공지', '제주', '특별자치도', '네이버', '동영상', '복권', '기금', '사업', '이내', '공식', '제주', '특별자치도', '포스트', '영훈', '지사', '청년', '다시', '도전', '조력자', '역할', '이내', '트위터', '영훈', '지사', '청년', '다시', '도전', '조력자', '역할', '오후', '도청', '탐라', '제주', '청년', '갭이어', '프로그램', '오리엔테이션', '제주', '도청', '보도자료', '트위터', '이내', '댓글', '리트윗', '메세지', '제주', '특별자치도', '네이버', '동영상', '영훈', '지사', '청년', '다시', '도전', '조력자', '역할', '공식', '제주', '특별자치도', '블로그', '제주도', '상반기', '지방', '재정', '최우수', '광역', '자치', '단체', '선정', '공식', '제주', '특별자치도', '블로그', '제주', '최고', '자연', '휴양', '공간', '왈도', '공원', '어제', '트위터', '치유', '휴식', '공간', '국내', '최초', '곶자왈', '조성', '야영장', '생태', '체험', '여러', '가지', '시설', '마음', '휴식', '트위터', '어제', '댓글', '리트윗', '메세지', '공식', '제주', '특별자치도', '블로그', '영훈', '지사', '청년', '다시', '도전', '조력자', '역할', '제주', '특별자치도', '네이버', '동영상', '영훈', '지사', '도내', '의료', '기관', '코로나', '대응', '체계', '정비', '이전', '다음', '경로', '지정', '별로', '호출', '별로', '호출', '클래스', '추가', '모듈', '초기', '루트', '요소', '사이트', '검색', '버튼', '클릭', '이벤트', '등록', '사이트', '검색', '버튼', '클릭', '이벤트', '등록', '제주', '특별자치도', '지역', '보기', '전체', '여행', '콘텐츠', '상품', '예약', '도시정보', '도시정보', '한국', '중국', '일본', '극동', '지역', '중앙', '지정학적', '전체', '바다로', '수리', '동경', '북위', '위치', '북단', '북위', '제주시', '추자면', '서리', '남단', '북위', '서귀포시', '대정읍', '마라도', '한국', '남단', '도로', '제주도', '포함', '유인도', '무인도', '가운데', '유인도', '우도', '상추자도', '하추자도', '비양도', '횡간도', '포도', '가파도', '마라도', '남북', '간의', '거리', '동서', '거리', '동서로', '모양', '러시아', '중국', '대륙', '일본', '동남아', '등지', '요충지', '천혜', '자연', '경관', '수려', '세계', '휴양', '관광지', '관련', '비짓', '제주', '지도', '행정구역', '제주시', '서귀포시', '날씨', '정보', '구름', '구름', '어제', '체감온도', '미세먼지', '초미세먼지', '오존', '지수', '보통', '구름', '구름', '구름', '구름', '구름', '구름', '돼지', '오메', '미로', '공원', '고등', '어회', '전복', '뚝배기', '성게', '미역국', '갈치', '제주', '제주', '특별자치도', '숙소', '호텔', '제주', '제주', '특별자치도', '강원도', '강원도', '부산', '부산광역시', '서울', '서울특별시', '경기도', '경기도', '인천', '인천광역시', '충북', '충청북도', '충남', '충청남도', '경북', '경상북도', '경남', '경상남도', '전북', '전라북도', '전남', '전라남도', '롯데', '호텔', '제주', '큐브', '리조트', '제주', '제이', '클로이', '다인', '리조트', '제주', '제주', '제주', '특별자치도', '제주시', '제주시', '제주', '특별자치도', '서귀포시', '서귀포시', '한국', '중국', '일본', '극동', '지역', '중앙', '지정학적', '전체', '바다로', '수리', '동경', '북위', '위치', '북단', '북위', '제주시', '추자면', '서리', '남단', '북위', '서귀포시', '대정읍', '마라도', '한국', '남단', '도로', '제주도', '포함', '유인도', '무인도', '가운데', '유인도', '우도', '상추자도', '하추자도', '비양도', '횡간도', '포도', '가파도', '마라도', '남북', '간의' ...

# %%
import pandas as pd
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

rc('font',family='Malgun Gothic') # 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series, columns=['jeju'])
df10 = df.sort_values(by='jeju',ascending=False)[:10]
df10.reset_index(inplace=True)
df10
# Out:
#   index  jeju
# 0   제주도   110
# 1    제주    91
# 2   이미지    79
# 3    준비    66
# 4   검색어    35
# 5    저장    32
# 6    정보    31
# 7    갈치    31
# 8    여행    29
# 9    구름    29

# %%
sns.barplot(x='index', y='jeju', data=df10, orient='v')
# Out:
# <AxesSubplot:xlabel='index', ylabel='jeju'>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=2000,height=1500).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1999.5, 1499.5, -0.5)
